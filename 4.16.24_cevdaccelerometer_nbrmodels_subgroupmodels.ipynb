# %%
require(foreign)
require(ggplot2)
require(MASS)
# Out:
# Loading required package: foreign
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘foreign’”
# Loading required package: ggplot2
#
# Loading required package: MASS

# %%
#use comorbid_sum to prevent collinearity

# %%
import_file <- "cevd_first_model.csv"
data <- read.csv(import_file)

# %%
num_rows <- nrow(data)
print(num_rows)
# Out:
# [1] 76079

# %%
#count number of future CeVD events by type
data$cevd_event <- as.integer(data$cevd_event)
count_events <- sum(data$cevd_event == 0, na.rm = TRUE)
cat("Number of cevd diagnoses:", count_events, "\n")
# Out:
# Number of cevd diagnoses: 73938

# %%
#convert all PA behavior data to integers
data$pa_sleep_convert <- as.integer(data$pa_sleep_convert)
data$pa_sed_convert <- as.integer(data$pa_sed_convert)
data$pa_light_convert <- as.integer(data$pa_light_convert)
data$pa_mv_convert <- as.integer(data$pa_mv_convert)

# %%
#count number of future CeVD events by type
data$f01_event <- as.integer(data$f01_event)
count_events <- sum(data$f01_event == 1, na.rm = TRUE)
cat("Number of future F01 diagnoses:", count_events, "\n")

data$g45_event <- as.integer(data$g45_event)
count_events <- sum(data$g45_event == 1, na.rm = TRUE)
cat("Number of future g45 diagnoses:", count_events, "\n")

data$g46_event <- as.integer(data$g46_event)
count_events <- sum(data$g46_event == 1, na.rm = TRUE)
cat("Number of future g46 diagnoses:", count_events, "\n")

data$h34_event <- as.integer(data$h34_event)
count_events <- sum(data$h34_event == 1, na.rm = TRUE)
cat("Number of future h34 diagnoses:", count_events, "\n")

data$i60_event <- as.integer(data$i60_event)
count_events <- sum(data$i60_event == 1, na.rm = TRUE)
cat("Number of future i60 diagnoses:", count_events, "\n")

data$i61_event <- as.integer(data$i61_event)
count_events <- sum(data$i61_event == 1, na.rm = TRUE)
cat("Number of future i61 diagnoses:", count_events, "\n")

data$i62_event <- as.integer(data$i62_event)
count_events <- sum(data$i62_event == 1, na.rm = TRUE)
cat("Number of future i62 diagnoses:", count_events, "\n")

data$i63_event <- as.integer(data$i63_event)
count_events <- sum(data$i63_event == 1, na.rm = TRUE)
cat("Number of future i63 diagnoses:", count_events, "\n")

data$i64_event <- as.integer(data$i64_event)
count_events <- sum(data$i64_event == 1, na.rm = TRUE)
cat("Number of future i64 diagnoses:", count_events, "\n")

data$i65_event <- as.integer(data$i65_event)
count_events <- sum(data$i65_event == 1, na.rm = TRUE)
cat("Number of future i65 diagnoses:", count_events, "\n")

data$i66_event <- as.integer(data$i66_event)
count_events <- sum(data$i66_event == 1, na.rm = TRUE)
cat("Number of future i66 diagnoses:", count_events, "\n")

data$i67_event <- as.integer(data$i67_event)
count_events <- sum(data$i67_event == 1, na.rm = TRUE)
cat("Number of future i67 diagnoses:", count_events, "\n")

data$i68_event <- as.integer(data$i68_event)
count_events <- sum(data$i68_event == 1, na.rm = TRUE)
cat("Number of future i68 diagnoses:", count_events, "\n")

data$i69_event <- as.integer(data$i69_event)
count_events <- sum(data$i69_event == 1, na.rm = TRUE)
cat("Number of future i69 diagnoses:", count_events, "\n")
# Out:
# Number of future F01 diagnoses: 82
# Number of future g45 diagnoses: 456
# Number of future g46 diagnoses: 18
# Number of future h34 diagnoses: 136
# Number of future i60 diagnoses: 94
# Number of future i61 diagnoses: 155
# Number of future i62 diagnoses: 87
# Number of future i63 diagnoses: 660
# Number of future i64 diagnoses: 170
# Number of future i65 diagnoses: 192
# Number of future i66 diagnoses: 12
# Number of future i67 diagnoses: 776
# Number of future i68 diagnoses: 10
# Number of future i69 diagnoses: 118

# %%
#sleep mean and sd
mean_pa_sleep_convert <- mean(subset(data, cevd_event == 1)$pa_sleep_convert, na.rm = TRUE)
sd_pa_sleep_convert <- sd(subset(data, cevd_event == 1)$pa_sleep_convert, na.rm = TRUE)
cat("Mean sleep - exp:", mean_pa_sleep_convert, "\n")
cat("Standard Deviation sleep - exp:", sd_pa_sleep_convert, "\n")
mean_pa_sleep_convert <- mean(subset(data, cevd_event == 0)$pa_sleep_convert, na.rm = TRUE)
sd_pa_sleep_convert <- sd(subset(data, cevd_event == 0)$pa_sleep_convert, na.rm = TRUE)
cat("Mean sleep - control:", mean_pa_sleep_convert, "\n")
cat("Standard Deviation sleep - control:", sd_pa_sleep_convert, "\n")
#sed mean and sd
mean_pa_sed_convert <- mean(subset(data, cevd_event == 1)$pa_sed_convert, na.rm = TRUE)
sd_pa_sed_convert <- sd(subset(data, cevd_event == 1)$pa_sed_convert, na.rm = TRUE)
cat("Mean sed - exp':", mean_pa_sed_convert, "\n")
cat("Standard Deviation sed - exp':", sd_pa_sed_convert, "\n")
mean_pa_sed_convert <- mean(subset(data, cevd_event == 0)$pa_sed_convert, na.rm = TRUE)
sd_pa_sed_convert <- sd(subset(data, cevd_event == 0)$pa_sed_convert, na.rm = TRUE)
cat("Mean sed - control':", mean_pa_sed_convert, "\n")
cat("Standard Deviation sed - control':", sd_pa_sed_convert, "\n")
#lpa mean and sd
mean_pa_light_convert <- mean(subset(data, cevd_event == 1)$pa_light_convert, na.rm = TRUE)
sd_pa_light_convert <- sd(subset(data, cevd_event == 1)$pa_light_convert, na.rm = TRUE)
cat("Mean lpa - exp:", mean_pa_light_convert, "\n")
cat("Standard Deviation  lpa - exp:", sd_pa_light_convert, "\n")
mean_pa_light_convert <- mean(subset(data, cevd_event == 0)$pa_light_convert, na.rm = TRUE)
sd_pa_light_convert <- sd(subset(data, cevd_event == 0)$pa_light_convert, na.rm = TRUE)
cat("Mean of  lpa - control:", mean_pa_light_convert, "\n")
cat("Standard Deviation  lpa - control:", sd_pa_light_convert, "\n")
#mvpa mean and sd
mean_pa_mv_convert <- mean(subset(data, cevd_event == 1)$pa_mv_convert, na.rm = TRUE)
sd_pa_mv_convert <- sd(subset(data, cevd_event == 1)$pa_mv_convert, na.rm = TRUE)
cat("Mean mvpa - exp:", mean_pa_mv_convert, "\n")
cat("Standard Deviation mvpa - exp:", sd_pa_mv_convert, "\n")
mean_pa_mv_convert <- mean(subset(data, cevd_event == 0)$pa_mv_convert, na.rm = TRUE)
sd_pa_mv_convert <- sd(subset(data, cevd_event == 0)$pa_mv_convert, na.rm = TRUE)
cat("Mean mvpa - control':", mean_pa_mv_convert, "\n")
cat("Standard Deviation mvpa - control:", sd_pa_mv_convert, "\n")
# Out:
# Mean sleep - exp: 529.886
# Standard Deviation sleep - exp: 82.12298
# Mean sleep - control: 526.8121
# Standard Deviation sleep - control: 77.74592
# Mean sed - exp': 572.4596
# Standard Deviation sed - exp': 112.4249
# Mean sed - control': 563.4276
# Standard Deviation sed - control': 109.1563
# Mean lpa - exp: 297.8645
# Standard Deviation  lpa - exp: 101.8473
# Mean of  lpa - control: 306.5359
# Standard Deviation  lpa - control: 99.19297
# Mean mvpa - exp: 37.83139
# Standard Deviation mvpa - exp: 33.60594
# Mean mvpa - control': 41.23477
# Standard Deviation mvpa - control: 34.66353

# %%
#create binary age variable
data$age_i0 <- as.integer(data$age_i0, na.rm = TRUE)
data$age_levels <- ifelse(data$age_i0 < 60, 0, 1)
data$age_levels <- as.integer(data$age_levels)
head(data$age_levels)
# Out:
# [1] 0 0 0 0 0 1

# %%
#unadjusted sleep IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event, data = data,
#     init.theta = 44.24175829, link = log)
#
# Coefficients:
#              Estimate Std. Error   z value Pr(>|z|)
# (Intercept) 6.2668440  0.0005757 10886.426   <2e-16 ***
# cevd_event  0.0058179  0.0034308     1.696   0.0899 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(44.2418) family taken to be 1)
#
#     Null deviance: 77923  on 76077  degrees of freedom
# Residual deviance: 77920  on 76076  degrees of freedom
#   (1 observation deleted due to missingness)
# AIC: 887646
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  44.242
#           Std. Err.:  0.249
#
#  2 x log-likelihood:  -887640.162
# Waiting for profiling to be done...
#             Estimate    2.5 %         97.5 %
# (Intercept) 6.266844009  6.2657159225 6.26797246
# cevd_event  0.005817945 -0.0009001971 0.01254814
# ...

# %%
#adjusted sleep IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 45.07017317, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.192e+00  7.916e-03 782.174  < 2e-16 ***
# cevd_event                   -3.851e-03  3.432e-03  -1.122  0.26172
# dias_bp_ave                  -1.166e-04  4.980e-05  -2.341  0.01925 *
# sys_bp_ave                    5.523e-04  8.745e-05   6.315 2.70e-10 ***
# white_yes                     2.973e-02  3.098e-03   9.595  < 2e-16 ***
# age_i0                        1.028e-03  9.238e-05  11.129  < 2e-16 ***
# male                         -1.393e-02  1.194e-03 -11.668  < 2e-16 ***
# ...

# %%
#udadjusted sed IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event, data = data, init.theta = 26.59492129,
#     link = log)
#
# Coefficients:
#              Estimate Std. Error  z value Pr(>|z|)
# (Intercept) 6.3340388  0.0007298 8679.521  < 2e-16 ***
# cevd_event  0.0159034  0.0043487    3.657 0.000255 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(26.5949) family taken to be 1)
#
#     Null deviance: 76686  on 76077  degrees of freedom
# Residual deviance: 76673  on 76076  degrees of freedom
#   (1 observation deleted due to missingness)
# AIC: 931839
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  26.595
#           Std. Err.:  0.142
#
#  2 x log-likelihood:  -931833.071
# Waiting for profiling to be done...
#             Estimate  2.5 %       97.5 %
# (Intercept) 6.3340388 6.332608751 6.33546939
# cevd_event  0.0159034 0.007390586 0.02443707
#             Estimate   2.5 %      97.5 %
# ...

# %%
#adjusted sed IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 29.08980126, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.099e+00  9.696e-03 629.033  < 2e-16 ***
# cevd_event                    9.646e-03  4.204e-03   2.295  0.02176 *
# dias_bp_ave                  -5.313e-04  6.104e-05  -8.705  < 2e-16 ***
# sys_bp_ave                    4.944e-04  1.072e-04   4.614 3.95e-06 ***
# white_yes                     7.025e-03  3.791e-03   1.853  0.06386 .
# age_i0                       -3.323e-04  1.132e-04  -2.937  0.00332 **
# male                          5.649e-02  1.462e-03  38.643  < 2e-16 ***
# ...

# %%
#unadjusted lpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event, data = data,
#     init.theta = 9.362475987, link = log)
#
# Coefficients:
#              Estimate Std. Error  z value Pr(>|z|)
# (Intercept)  5.725335   0.001220 4692.391  < 2e-16 ***
# cevd_event  -0.028696   0.007276   -3.944 8.02e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(9.3625) family taken to be 1)
#
#     Null deviance: 77698  on 76077  degrees of freedom
# Residual deviance: 77682  on 76076  degrees of freedom
#   (1 observation deleted due to missingness)
# AIC: 913702
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  9.3625
#           Std. Err.:  0.0489
#
#  2 x log-likelihood:  -913695.5640
# Waiting for profiling to be done...
#             Estimate    2.5 %       97.5 %
# (Intercept)  5.72533502  5.72294450  5.72772733
# cevd_event  -0.02869617 -0.04292742 -0.01440474
# ...

# %%
#adjusted lpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 10.34002069, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.132e+00  1.612e-02 380.344  < 2e-16 ***
# cevd_event                   -6.500e-03  6.997e-03  -0.929   0.3529
# dias_bp_ave                   1.043e-03  1.015e-04  10.280  < 2e-16 ***
# sys_bp_ave                   -1.606e-03  1.782e-04  -9.012  < 2e-16 ***
# white_yes                    -7.364e-02  6.301e-03 -11.687  < 2e-16 ***
# age_i0                       -8.336e-05  1.882e-04  -0.443   0.6579
# male                         -1.372e-01  2.433e-03 -56.382  < 2e-16 ***
# alc_freq_filter              -4.376e-03  1.740e-03  -2.515   0.0119 *
# ...

# %%
#unadjusted mvpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event, data = data, init.theta = 1.329889746,
#     link = log)
#
# Coefficients:
#             Estimate Std. Error  z value Pr(>|z|)
# (Intercept)  3.71928    0.00324 1147.903  < 2e-16 ***
# cevd_event  -0.08614    0.01934   -4.454 8.43e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(1.3299) family taken to be 1)
#
#     Null deviance: 86767  on 76077  degrees of freedom
# Residual deviance: 86747  on 76076  degrees of freedom
#   (1 observation deleted due to missingness)
# AIC: 716516
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  1.32989
#           Std. Err.:  0.00671
#
#  2 x log-likelihood:  -716510.35500
# Waiting for profiling to be done...
#             Estimate    2.5 %      97.5 %
# (Intercept)  3.71928177  3.7129377  3.72563850
# cevd_event  -0.08614266 -0.1238397 -0.04802354
#             Estimate   2.5 %      97.5 %
# ...

# %%
#adjusted mvpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 1.510002957, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9994390  0.0423552 118.036  < 2e-16 ***
# cevd_event                   -0.0380812  0.0183980  -2.070 0.038466 *
# dias_bp_ave                   0.0007949  0.0002667   2.980 0.002880 **
# sys_bp_ave                   -0.0005774  0.0004682  -1.233 0.217542
# white_yes                     0.0591005  0.0165854   3.563 0.000366 ***
# age_i0                       -0.0088269  0.0004939 -17.872  < 2e-16 ***
# male                          0.4310820  0.0063796  67.572  < 2e-16 ***
# alc_freq_filter               0.0690060  0.0045694  15.102  < 2e-16 ***
# ...

# %%
#convert all the time epoch data for each PA behavior to integers for analysis
data$pa_mv_day_1 <- as.integer(data$pa_mv_day_1)
data$pa_mv_day_2 <- as.integer(data$pa_mv_day_2)
data$pa_mv_day_3 <- as.integer(data$pa_mv_day_3)
data$pa_mv_day_4 <- as.integer(data$pa_mv_day_4)
data$pa_light_day_1 <- as.integer(data$pa_light_day_1)
data$pa_light_day_2 <- as.integer(data$pa_light_day_2)
data$pa_light_day_3 <- as.integer(data$pa_light_day_3)
data$pa_light_day_4 <- as.integer(data$pa_light_day_4)
data$pa_sed_day_1 <- as.integer(data$pa_sed_day_1)
data$pa_sed_day_2 <- as.integer(data$pa_sed_day_2)
data$pa_sed_day_3 <- as.integer(data$pa_sed_day_3)
data$pa_sed_day_4 <- as.integer(data$pa_sed_day_4)
data$pa_sleep_day_1 <- as.integer(data$pa_sleep_day_1)
data$pa_sleep_day_2 <- as.integer(data$pa_sleep_day_2)
data$pa_sleep_day_3 <- as.integer(data$pa_sleep_day_3)
data$pa_sleep_day_4 <- as.integer(data$pa_sleep_day_4)

# %%
#mvpa * irrr (adjusted) time periods = 1
summary(m1 <- glm.nb(pa_mv_day_1 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum+ gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_day_1 ~ cevd_event + +dias_bp_ave + sys_bp_ave +
#     white_yes + age_i0 + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 0.02812686762,
#     link = log)
#
# Coefficients:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   2.632845   0.330781   7.959 1.73e-15 ***
# cevd_event                    0.409269   0.145159   2.819 0.004811 **
# dias_bp_ave                   0.002769   0.002149   1.289 0.197482
# sys_bp_ave                   -0.002061   0.003740  -0.551 0.581497
# white_yes                    -0.738464   0.124469  -5.933 2.98e-09 ***
# age_i0                       -0.075724   0.003883 -19.500  < 2e-16 ***
# male                          1.116365   0.050270  22.207  < 2e-16 ***
# alc_freq_filter              -0.023833   0.036406  -0.655 0.512694
# ...

# %%
#mvpa * irrr (adjusted) time periods = 2_1
summary(m1 <- glm.nb(pa_mv_day_2 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_day_2 ~ cevd_event + +dias_bp_ave + sys_bp_ave +
#     white_yes + age_i0 + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 0.7855410287,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   3.5784296  0.0594941  60.148  < 2e-16 ***
# cevd_event                   -0.0662223  0.0257797  -2.569   0.0102 *
# dias_bp_ave                   0.0015346  0.0003737   4.107 4.01e-05 ***
# sys_bp_ave                   -0.0008888  0.0006566  -1.354   0.1758
# white_yes                     0.1282178  0.0233640   5.488 4.07e-08 ***
# age_i0                       -0.0037679  0.0006932  -5.436 5.46e-08 ***
# male                          0.4470937  0.0089443  49.986  < 2e-16 ***
# alc_freq_filter               0.0550534  0.0064089   8.590  < 2e-16 ***
# ...

# %%
#mvpa * irrr (adjusted) time periods = 3
summary(m1 <- glm.nb(pa_mv_day_3 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_day_3 ~ cevd_event + +dias_bp_ave + sys_bp_ave +
#     white_yes + age_i0 + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 1.170239518,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.003e+00  4.886e-02  81.914  < 2e-16 ***
# cevd_event                   -3.987e-02  2.118e-02  -1.883  0.05976 .
# dias_bp_ave                   4.666e-04  3.071e-04   1.519  0.12872
# sys_bp_ave                    5.828e-05  5.395e-04   0.108  0.91398
# white_yes                     9.548e-02  1.918e-02   4.979 6.41e-07 ***
# age_i0                       -3.242e-03  5.692e-04  -5.696 1.23e-08 ***
# male                          4.138e-01  7.347e-03  56.320  < 2e-16 ***
# alc_freq_filter               7.754e-02  5.264e-03  14.730  < 2e-16 ***
# ...

# %%
#mvpa * irrr (adjusted) time periods = 4
summary(m1 <- glm.nb(pa_mv_day_4 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_day_4 ~ cevd_event + +dias_bp_ave + sys_bp_ave +
#     white_yes + age_i0 + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 0.4183844676,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.612e+00  8.250e-02  55.908  < 2e-16 ***
# cevd_event                    4.933e-02  3.615e-02   1.365    0.172
# dias_bp_ave                  -5.972e-05  5.231e-04  -0.114    0.909
# sys_bp_ave                   -1.238e-03  9.170e-04  -1.350    0.177
# white_yes                    -1.328e-01  3.209e-02  -4.139 3.49e-05 ***
# age_i0                       -3.742e-02  9.620e-04 -38.896  < 2e-16 ***
# male                          4.269e-01  1.245e-02  34.294  < 2e-16 ***
# alc_freq_filter               7.390e-02  8.933e-03   8.272  < 2e-16 ***
# ...

# %%
#lpa * irrr (adjusted) time periods = 4
summary(m1 <- glm.nb(pa_light_day_4 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_day_4 ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 5.35875485, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.4458281  0.0229134 237.671  < 2e-16 ***
# cevd_event                    0.0097903  0.0099594   0.983 0.325596
# dias_bp_ave                   0.0005493  0.0001443   3.806 0.000141 ***
# sys_bp_ave                   -0.0023256  0.0002536  -9.171  < 2e-16 ***
# white_yes                    -0.1928141  0.0089233 -21.608  < 2e-16 ***
# age_i0                       -0.0080301  0.0002676 -30.006  < 2e-16 ***
# male                         -0.1189310  0.0034605 -34.368  < 2e-16 ***
# ...

# %%
#lpa * irrr (adjusted) time periods = 3
summary(m1 <- glm.nb(pa_light_day_3 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_day_3 ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 7.153318219, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9386782  0.0196916 250.801  < 2e-16 ***
# cevd_event                   -0.0099016  0.0085286  -1.161   0.2456
# dias_bp_ave                   0.0009394  0.0001237   7.593 3.12e-14 ***
# sys_bp_ave                   -0.0008917  0.0002175  -4.101 4.12e-05 ***
# white_yes                    -0.0175936  0.0077033  -2.284   0.0224 *
# age_i0                        0.0023299  0.0002299  10.137  < 2e-16 ***
# male                         -0.1741483  0.0029696 -58.643  < 2e-16 ***
# alc_freq_filter              -0.0037194  0.0021236  -1.751   0.0799 .
# ...

# %%
#lpa * irrr (adjusted) time periods = 2
summary(m1 <- glm.nb(pa_light_day_2 ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_day_2 ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 7.731130243, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.7631336  0.0190618 249.879  < 2e-16 ***
# cevd_event                   -0.0206751  0.0082561  -2.504   0.0123 *
# dias_bp_ave                   0.0015054  0.0001197  12.576  < 2e-16 ***
# sys_bp_ave                   -0.0017483  0.0002104  -8.308  < 2e-16 ***
# white_yes                    -0.0100292  0.0074581  -1.345   0.1787
# age_i0                        0.0040220  0.0002225  18.077  < 2e-16 ***
# male                         -0.1320345  0.0028740 -45.941  < 2e-16 ***
# ...

# %%
#lpa * irrr (adjusted) time periods = 1
summary(m1 <- glm.nb(pa_light_day_1 ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_day_1 ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 0.5650196417, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   2.6805071  0.0710097  37.748  < 2e-16 ***
# cevd_event                    0.1188057  0.0308207   3.855 0.000116 ***
# dias_bp_ave                   0.0014579  0.0004490   3.247 0.001166 **
# sys_bp_ave                   -0.0034536  0.0007880  -4.383 1.17e-05 ***
# white_yes                    -0.6115360  0.0273011 -22.400  < 2e-16 ***
# age_i0                       -0.0139678  0.0008311 -16.806  < 2e-16 ***
# male                          0.1755054  0.0107394  16.342  < 2e-16 ***
# ...

# %%
#sed * irrr (adjusted) time periods = 1
summary(m1 <- glm.nb(pa_sed_day_1 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_day_1 ~ cevd_event + +dias_bp_ave + sys_bp_ave +
#     white_yes + age_i0 + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 0.6362247611,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   1.888e+00  6.520e-02  28.955  < 2e-16 ***
# cevd_event                    1.759e-01  2.813e-02   6.252 4.04e-10 ***
# dias_bp_ave                  -5.678e-04  4.099e-04  -1.385    0.166
# sys_bp_ave                   -1.589e-05  7.201e-04  -0.022    0.982
# white_yes                    -4.723e-01  2.536e-02 -18.620  < 2e-16 ***
# age_i0                        4.859e-03  7.615e-04   6.381 1.76e-10 ***
# male                          2.091e-01  9.825e-03  21.280  < 2e-16 ***
# alc_freq_filter              -5.065e-02  7.037e-03  -7.197 6.14e-13 ***
# ...

# %%
#sed * irrr (adjusted) time periods = 2
summary(m1 <- glm.nb(pa_sed_day_2 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + age_i0  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_day_2 ~ cevd_event + +dias_bp_ave + sys_bp_ave +
#     white_yes + age_i0 + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 9.340992547,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9219663  0.0173131 284.291  < 2e-16 ***
# cevd_event                    0.0172502  0.0075029   2.299  0.02150 *
# dias_bp_ave                  -0.0007623  0.0001090  -6.997 2.61e-12 ***
# sys_bp_ave                    0.0005957  0.0001913   3.113  0.00185 **
# white_yes                     0.0112751  0.0067690   1.666  0.09577 .
# age_i0                       -0.0051699  0.0002020 -25.590  < 2e-16 ***
# male                          0.1005017  0.0026088  38.523  < 2e-16 ***
# alc_freq_filter               0.0060737  0.0018686   3.250  0.00115 **
# ...

# %%
#sed * irrr (adjusted) time periods = 3
summary(m1 <- glm.nb(pa_sed_day_3 ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_day_3 ~ cevd_event + +dias_bp_ave + sys_bp_ave +
#     white_yes + age_i0 + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 17.67493886,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.1740677  0.0126922 407.656  < 2e-16 ***
# cevd_event                    0.0033908  0.0054956   0.617 0.537232
# dias_bp_ave                  -0.0005108  0.0000798  -6.400 1.55e-10 ***
# sys_bp_ave                    0.0004800  0.0001402   3.424 0.000616 ***
# white_yes                     0.0192512  0.0049649   3.877 0.000106 ***
# age_i0                       -0.0013913  0.0001481  -9.395  < 2e-16 ***
# male                          0.0452220  0.0019122  23.649  < 2e-16 ***
# ...

# %%
#sed * irrr (adjusted) time periods = 4
summary(m1 <- glm.nb(pa_sed_day_4 ~ cevd_event + age_i0 +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_day_4 ~ cevd_event + age_i0 + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 22.31531846,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.853e+00  1.141e-02 425.364  < 2e-16 ***
# cevd_event                   -6.666e-03  4.929e-03  -1.352  0.17623
# age_i0                        4.021e-03  1.331e-04  30.210  < 2e-16 ***
# dias_bp_ave                  -3.999e-04  7.162e-05  -5.584 2.35e-08 ***
# sys_bp_ave                    5.496e-04  1.258e-04   4.367 1.26e-05 ***
# white_yes                     4.690e-02  4.470e-03  10.493  < 2e-16 ***
# male                          2.397e-02  1.717e-03  13.954  < 2e-16 ***
# ...

# %%
#sleep * irrr (adjusted) time periods = 4
summary(m1 <- glm.nb(pa_sleep_day_4 ~ cevd_event + age_i0 +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_day_4 ~ cevd_event + age_i0 + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 2.325382454,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.2551537  0.0340650 124.913  < 2e-16 ***
# cevd_event                    0.0048930  0.0147452   0.332 0.740013
# age_i0                       -0.0006075  0.0003975  -1.528 0.126437
# dias_bp_ave                   0.0005375  0.0002141   2.511 0.012045 *
# sys_bp_ave                    0.0011495  0.0003761   3.056 0.002243 **
# white_yes                     0.0731694  0.0133320   5.488 4.06e-08 ***
# male                          0.0089140  0.0051331   1.737 0.082462 .
# alc_freq_filter              -0.0395524  0.0036739 -10.766  < 2e-16 ***
# ...

# %%
#sleep * irrr (adjusted) time periods = 3
summary(m1 <- glm.nb(pa_sleep_day_3 ~ cevd_event + age_i0 +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_day_3 ~ cevd_event + age_i0 + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 0.5825918595,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   2.1488047  0.0682451  31.487  < 2e-16 ***
# cevd_event                    0.0871364  0.0294714   2.957 0.003110 **
# age_i0                        0.0037260  0.0007969   4.676 2.93e-06 ***
# dias_bp_ave                  -0.0015941  0.0004290  -3.716 0.000202 ***
# sys_bp_ave                    0.0027489  0.0007536   3.647 0.000265 ***
# white_yes                    -0.2181733  0.0265963  -8.203 2.34e-16 ***
# male                          0.2173441  0.0102826  21.137  < 2e-16 ***
# ...

# %%
#sleep * irrr (adjusted) time periods = 2
summary(m1 <- glm.nb(pa_sleep_day_2 ~ cevd_event + age_i0 + +dias_bp_ave+ sys_bp_ave + white_yes  +  male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_day_2 ~ cevd_event + age_i0 + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 4.266899731,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.3556471  0.0252750 172.330  < 2e-16 ***
# cevd_event                    0.0057912  0.0109322   0.530   0.5963
# age_i0                        0.0036463  0.0002950  12.360  < 2e-16 ***
# dias_bp_ave                  -0.0008260  0.0001588  -5.201 1.98e-07 ***
# sys_bp_ave                    0.0012476  0.0002790   4.471 7.79e-06 ***
# white_yes                    -0.0268462  0.0098825  -2.717   0.0066 **
# male                         -0.0568080  0.0038092 -14.913  < 2e-16 ***
# alc_freq_filter               0.0033443  0.0027255   1.227   0.2198
# ...

# %%
#sleep * irrr (adjusted) time periods = 1
summary(m1 <- glm.nb(pa_sleep_day_1 ~ cevd_event + age_i0 +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_day_1 ~ cevd_event + age_i0 + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 92.91393419,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.833e+00  6.010e-03 970.617  < 2e-16 ***
# cevd_event                   -1.565e-02  2.605e-03  -6.006 1.90e-09 ***
# age_i0                        2.482e-04  7.007e-05   3.542 0.000397 ***
# dias_bp_ave                   1.097e-05  3.774e-05   0.291 0.771222
# sys_bp_ave                    8.731e-05  6.632e-05   1.316 0.188059
# white_yes                     5.222e-02  2.362e-03  22.109  < 2e-16 ***
# male                         -1.629e-02  9.051e-04 -17.996  < 2e-16 ***
# alc_freq_filter               5.796e-03  6.476e-04   8.950  < 2e-16 ***
# ...

# %%
#

# %%
#subgroup analyses

# %%
#

# %%
#create 2 age subgroups
data_age_0 <- data[data$age_levels == 0, ]
data_age_1 <- data[data$age_levels == 1, ]

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~  cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter+ dep_diag_yes, data = data_age_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_0,
#     init.theta = 43.12353071, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.244e+00  8.067e-03 773.967  < 2e-16 ***
# cevd_event                    6.252e-05  5.817e-03   0.011  0.99142
# dias_bp_ave                   2.721e-05  6.892e-05   0.395  0.69304
# sys_bp_ave                    4.132e-04  1.176e-04   3.515  0.00044 ***
# white_yes                     3.320e-02  3.542e-03   9.375  < 2e-16 ***
# male                         -2.264e-02  1.531e-03 -14.785  < 2e-16 ***
# alc_freq_filter              -5.212e-03  1.113e-03  -4.684 2.81e-06 ***
# smok_filter                   1.229e-03  1.489e-03   0.825  0.40910
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_age_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_1,
#     init.theta = 49.05001628, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.243e+00  1.153e-02 541.604  < 2e-16 ***
# cevd_event                   -4.519e-03  4.133e-03  -1.093 0.274201
# dias_bp_ave                  -4.996e-05  6.917e-05  -0.722 0.470139
# sys_bp_ave                    4.969e-04  1.309e-04   3.796 0.000147 ***
# white_yes                     2.191e-02  6.625e-03   3.308 0.000941 ***
# male                          1.077e-03  1.916e-03   0.562 0.574126
# alc_freq_filter              -8.916e-03  1.317e-03  -6.769 1.30e-11 ***
# smok_filter                   4.976e-04  1.855e-03   0.268 0.788523
# ...

# %%
#p for interaction
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event *age_levels +  +dias_bp_ave+ sys_bp_ave + white_yes+ male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event * age_levels +
#     +dias_bp_ave + sys_bp_ave + white_yes + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 45.01439097, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.240e+00  6.477e-03 963.396  < 2e-16 ***
# cevd_event                   -2.976e-04  5.697e-03  -0.052  0.95834
# age_levels                    9.278e-03  1.486e-03   6.245 4.23e-10 ***
# dias_bp_ave                  -3.326e-05  4.917e-05  -0.676  0.49879
# sys_bp_ave                    4.680e-04  8.732e-05   5.360 8.34e-08 ***
# white_yes                     3.125e-02  3.096e-03  10.096  < 2e-16 ***
# male                         -1.400e-02  1.195e-03 -11.715  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_age_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_0,
#     init.theta = 27.60934573, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.094e+00  9.925e-03 613.993  < 2e-16 ***
# cevd_event                   -8.078e-03  7.157e-03  -1.129    0.259
# dias_bp_ave                  -9.114e-04  8.483e-05 -10.745  < 2e-16 ***
# sys_bp_ave                    9.754e-04  1.446e-04   6.744 1.54e-11 ***
# white_yes                     5.203e-03  4.352e-03   1.195    0.232
# male                          6.137e-02  1.883e-03  32.591  < 2e-16 ***
# alc_freq_filter               5.398e-03  1.369e-03   3.943 8.06e-05 ***
# smok_filter                  -8.905e-03  1.832e-03  -4.862 1.16e-06 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_age_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_1,
#     init.theta = 32.54734431, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0291157  0.0139249 432.974  < 2e-16 ***
# cevd_event                    0.0161036  0.0049909   3.227 0.001253 **
# dias_bp_ave                  -0.0003164  0.0000836  -3.785 0.000154 ***
# sys_bp_ave                    0.0003074  0.0001582   1.943 0.051998 .
# white_yes                     0.0075250  0.0079992   0.941 0.346848
# male                          0.0485174  0.0023151  20.957  < 2e-16 ***
# alc_freq_filter               0.0032294  0.0015918   2.029 0.042479 *
# smok_filter                  -0.0026420  0.0022419  -1.178 0.238621
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event *age_levels +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * age_levels + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 29.09394762,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.081e+00  7.928e-03 767.033  < 2e-16 ***
# cevd_event                   -1.039e-02  6.974e-03  -1.490 0.136340
# age_levels                    4.290e-03  1.819e-03   2.358 0.018375 *
# dias_bp_ave                  -6.176e-04  6.023e-05 -10.255  < 2e-16 ***
# sys_bp_ave                    6.041e-04  1.069e-04   5.650 1.61e-08 ***
# white_yes                     6.000e-03  3.786e-03   1.585 0.112993
# male                          5.624e-02  1.463e-03  38.437  < 2e-16 ***
# ...

# %%
# Fit negative binomial regression model for smokers
model_young <- glm.nb(pa_sed_convert ~ cevd_event + male + alc_freq_filter + smok_filter + bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = subset(data, age_levels == 0))

# Fit negative binomial regression model for non-smokers
model_old <- glm.nb(pa_sed_convert ~ cevd_event + male + alc_freq_filter + smok_filter + bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = subset(data, age_levels == 1))

# Compare models and assess interaction
anova(model_young, model_old, test = "Chisq")
# Out:
#   Model
# 1 cevd_event + male + alc_freq_filter + smok_filter + bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes
# 2 cevd_event + male + alc_freq_filter + smok_filter + bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes
#   theta    Resid. df    2 x log-lik. Test      df LR stat. Pr(Chi)
# 1 27.30198 48855     -597355.2                 NA       NA NA
# 2 31.89669 27201     -328512.4       1 vs 2 21654 268842.8  0

# %%
model <- glm.nb(pa_sed_convert ~ cevd_event * age_levels + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data)

# View summary of the model
summary(model)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * age_levels + male +
#     alc_freq_filter + smok_filter + bmi + full_screen_time +
#     employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +
#     dep_diag_yes, data = data, init.theta = 29.04907636, link = log)
#
# Coefficients:
#                                Estimate Std. Error  z value Pr(>|z|)
# (Intercept)                   6.0560540  0.0051097 1185.196  < 2e-16 ***
# cevd_event                   -0.0120252  0.0069771   -1.724 0.084793 .
# age_levels                    0.0002993  0.0017737    0.169 0.866006
# male                          0.0549938  0.0014501   37.924  < 2e-16 ***
# alc_freq_filter               0.0041965  0.0010366    4.049 5.15e-05 ***
# smok_filter                  -0.0066794  0.0014242   -4.690 2.73e-06 ***
# bmi                           0.0067059  0.0001640   40.885  < 2e-16 ***
# full_screen_time              0.0109764  0.0003381   32.461  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_age_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_0,
#     init.theta = 9.938906236, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0957807  0.0164074 371.526  < 2e-16 ***
# cevd_event                    0.0181649  0.0118349   1.535    0.125
# dias_bp_ave                   0.0014029  0.0001402  10.006  < 2e-16 ***
# sys_bp_ave                   -0.0020835  0.0002392  -8.711  < 2e-16 ***
# white_yes                    -0.0733613  0.0071924 -10.200  < 2e-16 ***
# male                         -0.1304676  0.0031163 -41.866  < 2e-16 ***
# alc_freq_filter              -0.0091525  0.0022639  -4.043 5.28e-05 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_age_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_1,
#     init.theta = 11.28605599, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.2378025  0.0234141 266.412  < 2e-16 ***
# cevd_event                   -0.0167518  0.0084039  -1.993   0.0462 *
# dias_bp_ave                   0.0006793  0.0001406   4.833 1.34e-06 ***
# sys_bp_ave                   -0.0013511  0.0002661  -5.078 3.82e-07 ***
# white_yes                    -0.0633698  0.0134453  -4.713 2.44e-06 ***
# male                         -0.1502548  0.0038945 -38.582  < 2e-16 ***
# alc_freq_filter               0.0035794  0.0026765   1.337   0.1811
# smok_filter                   0.0091524  0.0037704   2.427   0.0152 *
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event *age_levels +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event * age_levels +
#     +dias_bp_ave + sys_bp_ave + white_yes + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 10.34205725, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1304579  0.0131834 465.013  < 2e-16 ***
# cevd_event                    0.0222008  0.0115983   1.914  0.05560 .
# age_levels                   -0.0058751  0.0030262  -1.941  0.05221 .
# dias_bp_ave                   0.0010837  0.0001001  10.823  < 2e-16 ***
# sys_bp_ave                   -0.0016658  0.0001779  -9.366  < 2e-16 ***
# white_yes                    -0.0733182  0.0062916 -11.653  < 2e-16 ***
# male                         -0.1369273  0.0024347 -56.239  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_age_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_0,
#     init.theta = 1.569943194, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.5528164  0.0415008 109.704  < 2e-16 ***
# cevd_event                   -0.0235657  0.0299109  -0.788 0.430775
# dias_bp_ave                   0.0014518  0.0003543   4.098 4.17e-05 ***
# sys_bp_ave                   -0.0020400  0.0006042  -3.376 0.000735 ***
# white_yes                     0.0515419  0.0182171   2.829 0.004665 **
# male                          0.4001395  0.0078584  50.919  < 2e-16 ***
# alc_freq_filter               0.0687477  0.0057157  12.028  < 2e-16 ***
# smok_filter                  -0.0020752  0.0076471  -0.271 0.786102
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_age_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_age_1,
#     init.theta = 1.417532093, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.5895885  0.0663526  69.170  < 2e-16 ***
# cevd_event                   -0.0519940  0.0237866  -2.186  0.02883 *
# dias_bp_ave                  -0.0002802  0.0003980  -0.704  0.48131
# sys_bp_ave                    0.0011602  0.0007532   1.540  0.12346
# white_yes                     0.0605012  0.0381475   1.586  0.11274
# male                          0.4903689  0.0110094  44.541  < 2e-16 ***
# alc_freq_filter               0.0609847  0.0075720   8.054 8.01e-16 ***
# smok_filter                  -0.0325201  0.0106650  -3.049  0.00229 **
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event *age_levels +  +dias_bp_ave+ sys_bp_ave + white_yes +male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event * age_levels + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 1.510087075,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.6041113  0.0346703 132.797  < 2e-16 ***
# cevd_event                   -0.0203319  0.0304517  -0.668  0.50434
# age_levels                   -0.1385603  0.0079500 -17.429  < 2e-16 ***
# dias_bp_ave                   0.0005350  0.0002632   2.033  0.04208 *
# sys_bp_ave                   -0.0004907  0.0004673  -1.050  0.29364
# white_yes                     0.0503134  0.0165620   3.038  0.00238 **
# male                          0.4340186  0.0063856  67.969  < 2e-16 ***
# alc_freq_filter               0.0666765  0.0045619  14.616  < 2e-16 ***
# ...

# %%
#create male subgroups
data_male_0 <- data[data$male == 0, ]
data_male_1 <- data[data$male == 1, ]

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_0,
#     init.theta = 1.396967697, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.1118561  0.0571249  89.486  < 2e-16 ***
# cevd_event                   -0.0264305  0.0278177  -0.950    0.342
# dias_bp_ave                   0.0005607  0.0003605   1.555    0.120
# sys_bp_ave                    0.0003265  0.0006485   0.503    0.615
# white_yes                     0.0329264  0.0225989   1.457    0.145
# age_i0                       -0.0101678  0.0006886 -14.767  < 2e-16 ***
# alc_freq_filter               0.0696441  0.0061898  11.251  < 2e-16 ***
# smok_filter                  -0.0093839  0.0085826  -1.093    0.274
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_1,
#     init.theta = 1.686612538, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.2101797  0.0650843  80.053  < 2e-16 ***
# cevd_event                   -0.0528088  0.0239953  -2.201  0.02775 *
# dias_bp_ave                   0.0014229  0.0003989   3.567  0.00036 ***
# sys_bp_ave                   -0.0019563  0.0006724  -2.909  0.00362 **
# white_yes                     0.0968140  0.0242901   3.986 6.73e-05 ***
# age_i0                       -0.0070367  0.0007042  -9.992  < 2e-16 ***
# alc_freq_filter               0.0643859  0.0067567   9.529  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event *male +  +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event * male + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 1.510003073,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9994470  0.0423554 118.036  < 2e-16 ***
# cevd_event                   -0.0396979  0.0267205  -1.486 0.137367
# male                          0.4309952  0.0064631  66.685  < 2e-16 ***
# dias_bp_ave                   0.0007952  0.0002667   2.981 0.002874 **
# sys_bp_ave                   -0.0005777  0.0004682  -1.234 0.217292
# white_yes                     0.0591017  0.0165854   3.563 0.000366 ***
# age_i0                       -0.0088267  0.0004939 -17.871  < 2e-16 ***
# alc_freq_filter               0.0690047  0.0045695  15.101  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_0,
#     init.theta = 11.87488966, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1502617  0.0195179 315.109  < 2e-16 ***
# cevd_event                   -0.0039995  0.0094761  -0.422 0.672979
# dias_bp_ave                   0.0010973  0.0001231   8.917  < 2e-16 ***
# sys_bp_ave                   -0.0018208  0.0002214  -8.223  < 2e-16 ***
# white_yes                    -0.0773499  0.0077060 -10.038  < 2e-16 ***
# age_i0                        0.0005063  0.0002354   2.150 0.031517 *
# alc_freq_filter              -0.0070353  0.0021159  -3.325 0.000884 ***
# smok_filter                   0.0024469  0.0029331   0.834 0.404140
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_1,
#     init.theta = 8.817379816, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.9606861  0.0283946 209.923  < 2e-16 ***
# cevd_event                   -0.0079081  0.0104546  -0.756 0.449396
# dias_bp_ave                   0.0008283  0.0001740   4.760 1.94e-06 ***
# sys_bp_ave                   -0.0012184  0.0002933  -4.153 3.28e-05 ***
# white_yes                    -0.0686700  0.0105738  -6.494 8.34e-11 ***
# age_i0                       -0.0007935  0.0003075  -2.581 0.009859 **
# alc_freq_filter              -0.0004351  0.0029487  -0.148 0.882703
# smok_filter                   0.0308704  0.0039254   7.864 3.71e-15 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event *male +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event * male + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 10.3401206,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.132e+00  1.612e-02 380.341  < 2e-16 ***
# cevd_event                   -3.196e-04  1.010e-02  -0.032   0.9748
# male                         -1.368e-01  2.465e-03 -55.510  < 2e-16 ***
# dias_bp_ave                   1.042e-03  1.015e-04  10.267  < 2e-16 ***
# sys_bp_ave                   -1.605e-03  1.782e-04  -9.005  < 2e-16 ***
# white_yes                    -7.363e-02  6.301e-03 -11.686  < 2e-16 ***
# age_i0                       -8.348e-05  1.882e-04  -0.443   0.6574
# alc_freq_filter              -4.369e-03  1.740e-03  -2.510   0.0121 *
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_0,
#     init.theta = 29.44878309, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.054e+00  1.250e-02 484.359  < 2e-16 ***
# cevd_event                    1.114e-02  6.065e-03   1.837   0.0662 .
# dias_bp_ave                  -6.418e-04  7.882e-05  -8.144 3.84e-16 ***
# sys_bp_ave                    6.758e-04  1.418e-04   4.767 1.87e-06 ***
# white_yes                     1.135e-02  4.938e-03   2.299   0.0215 *
# age_i0                        1.686e-05  1.508e-04   0.112   0.9109
# alc_freq_filter               5.431e-03  1.355e-03   4.009 6.10e-05 ***
# smok_filter                   2.348e-03  1.878e-03   1.251   0.2111
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + age_i0 +  +dias_bp_ave+ sys_bp_ave + white_yes  + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + age_i0 + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_1,
#     init.theta = 28.73111798, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.225e+00  1.586e-02 392.441  < 2e-16 ***
# cevd_event                    8.903e-03  5.838e-03   1.525  0.12724
# age_i0                       -7.614e-04  1.718e-04  -4.433 9.29e-06 ***
# dias_bp_ave                  -4.083e-04  9.722e-05  -4.200 2.67e-05 ***
# sys_bp_ave                    2.768e-04  1.638e-04   1.689  0.09120 .
# white_yes                     6.654e-04  5.910e-03   0.113  0.91035
# alc_freq_filter               4.332e-03  1.647e-03   2.630  0.00854 **
# smok_filter                  -1.755e-02  2.193e-03  -8.005 1.20e-15 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event *male +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * male + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data, init.theta = 29.09009566,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.099e+00  9.696e-03 629.030  < 2e-16 ***
# cevd_event                    1.341e-02  6.082e-03   2.205  0.02748 *
# male                          5.669e-02  1.481e-03  38.278  < 2e-16 ***
# dias_bp_ave                  -5.319e-04  6.104e-05  -8.714  < 2e-16 ***
# sys_bp_ave                    4.951e-04  1.072e-04   4.621 3.83e-06 ***
# white_yes                     7.025e-03  3.791e-03   1.853  0.06386 .
# age_i0                       -3.328e-04  1.132e-04  -2.940  0.00328 **
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_0,
#     init.theta = 50.11674782, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.216e+00  9.767e-03 636.509  < 2e-16 ***
# cevd_event                   -8.078e-03  4.740e-03  -1.704 0.088293 .
# dias_bp_ave                  -4.376e-05  6.156e-05  -0.711 0.477097
# sys_bp_ave                    4.519e-04  1.107e-04   4.081 4.49e-05 ***
# white_yes                     3.245e-02  3.862e-03   8.401  < 2e-16 ***
# age_i0                        3.304e-04  1.178e-04   2.806 0.005021 **
# alc_freq_filter              -5.094e-03  1.058e-03  -4.813 1.49e-06 ***
# smok_filter                  -3.062e-03  1.467e-03  -2.087 0.036877 *
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_male_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_male_1,
#     init.theta = 39.85292711, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.144e+00  1.365e-02 450.205  < 2e-16 ***
# cevd_event                   -1.495e-03  5.019e-03  -0.298  0.76584
# dias_bp_ave                  -1.113e-04  8.358e-05  -1.332  0.18300
# sys_bp_ave                    6.064e-04  1.409e-04   4.303 1.68e-05 ***
# white_yes                     2.732e-02  5.089e-03   5.368 7.97e-08 ***
# age_i0                        1.872e-03  1.478e-04  12.670  < 2e-16 ***
# alc_freq_filter              -1.005e-02  1.416e-03  -7.095 1.29e-12 ***
# smok_filter                   5.298e-03  1.886e-03   2.809  0.00497 **
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event *male +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event * male + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 45.0739039,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.192e+00  7.916e-03 782.207  < 2e-16 ***
# cevd_event                   -1.236e-02  4.961e-03  -2.493  0.01268 *
# male                         -1.439e-02  1.209e-03 -11.898  < 2e-16 ***
# dias_bp_ave                  -1.153e-04  4.981e-05  -2.315  0.02059 *
# sys_bp_ave                    5.509e-04  8.745e-05   6.300 2.98e-10 ***
# white_yes                     2.973e-02  3.098e-03   9.595  < 2e-16 ***
# age_i0                        1.029e-03  9.238e-05  11.139  < 2e-16 ***
# ...

# %%
# Create smoking subgroups
data$smoking_filter <- ifelse(data$smok_stat > 0, 1, 0)
data_smoking_0 <- data[data$smoking_filter == 0, ]
data_smoking_1 <- data[data$smoking_filter == 1, ]

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + male +  +dias_bp_ave+ sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + male + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi +
#     full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_0,
#     init.theta = 44.8223211, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.180e+00  1.047e-02 590.474  < 2e-16 ***
# cevd_event                   -3.705e-03  4.981e-03  -0.744  0.45697
# male                         -1.924e-02  1.602e-03 -12.007  < 2e-16 ***
# dias_bp_ave                  -6.358e-05  6.724e-05  -0.946  0.34440
# sys_bp_ave                    4.788e-04  1.185e-04   4.042 5.29e-05 ***
# white_yes                     3.224e-02  3.835e-03   8.408  < 2e-16 ***
# alc_freq_filter              -5.549e-03  1.163e-03  -4.770 1.84e-06 ***
# age_i0                        9.969e-04  1.230e-04   8.104 5.32e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + male +  +dias_bp_ave+ sys_bp_ave + white_yes  + alc_freq_filter + age_i0 + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + male + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi +
#     full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_1,
#     init.theta = 45.4507673, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.212e+00  1.232e-02 504.373  < 2e-16 ***
# cevd_event                   -4.122e-03  4.728e-03  -0.872   0.3833
# male                         -7.075e-03  1.794e-03  -3.943 8.04e-05 ***
# dias_bp_ave                  -1.855e-04  7.411e-05  -2.503   0.0123 *
# sys_bp_ave                    6.397e-04  1.296e-04   4.935 8.03e-07 ***
# white_yes                     2.503e-02  5.287e-03   4.734 2.20e-06 ***
# alc_freq_filter              -8.703e-03  1.259e-03  -6.910 4.84e-12 ***
# age_i0                        1.049e-03  1.401e-04   7.486 7.12e-14 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event *smok_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + male + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event * smok_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 45.07017403, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.192e+00  7.916e-03 782.160  < 2e-16 ***
# cevd_event                   -3.723e-03  4.949e-03  -0.752  0.45186
# smok_filter                   1.010e-03  1.179e-03   0.857  0.39168
# dias_bp_ave                  -1.166e-04  4.980e-05  -2.341  0.01925 *
# sys_bp_ave                    5.523e-04  8.745e-05   6.315 2.70e-10 ***
# white_yes                     2.973e-02  3.098e-03   9.595  < 2e-16 ***
# age_i0                        1.028e-03  9.239e-05  11.128  < 2e-16 ***
# alc_freq_filter              -6.932e-03  8.540e-04  -8.117 4.77e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + male +  +dias_bp_ave+ sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + male + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi +
#     full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_0,
#     init.theta = 29.23815509, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.108e+00  1.276e-02 478.760  < 2e-16 ***
# cevd_event                    8.965e-03  6.073e-03   1.476  0.13989
# male                          6.648e-02  1.952e-03  34.052  < 2e-16 ***
# dias_bp_ave                  -5.861e-04  8.201e-05  -7.146 8.92e-13 ***
# sys_bp_ave                    5.957e-04  1.444e-04   4.125 3.71e-05 ***
# white_yes                     8.465e-03  4.670e-03   1.813  0.06984 .
# alc_freq_filter               5.727e-03  1.418e-03   4.038 5.39e-05 ***
# age_i0                       -6.128e-04  1.499e-04  -4.087 4.37e-05 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + age_i0 + alc_freq_filter  + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + age_i0 + alc_freq_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_1,
#     init.theta = 28.9991241, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0762594  0.0151652 400.671  < 2e-16 ***
# cevd_event                    0.0104640  0.0058222   1.797   0.0723 .
# dias_bp_ave                  -0.0004536  0.0000913  -4.969 6.74e-07 ***
# sys_bp_ave                    0.0003783  0.0001597   2.369   0.0178 *
# white_yes                     0.0022373  0.0065032   0.344   0.7308
# male                          0.0429269  0.0022098  19.426  < 2e-16 ***
# age_i0                        0.0001283  0.0001726   0.743   0.4573
# alc_freq_filter               0.0035243  0.0015515   2.272   0.0231 *
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event *smok_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + male + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * smok_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 29.08994652, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.099e+00  9.696e-03 629.027  < 2e-16 ***
# cevd_event                    7.021e-03  6.064e-03   1.158   0.2470
# smok_filter                  -6.558e-03  1.445e-03  -4.539 5.66e-06 ***
# dias_bp_ave                  -5.313e-04  6.104e-05  -8.705  < 2e-16 ***
# sys_bp_ave                    4.944e-04  1.072e-04   4.614 3.95e-06 ***
# white_yes                     7.006e-03  3.791e-03   1.848   0.0646 .
# age_i0                       -3.315e-04  1.132e-04  -2.929   0.0034 **
# alc_freq_filter               4.694e-03  1.046e-03   4.485 7.28e-06 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + age_i0 + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + age_i0 +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_0,
#     init.theta = 10.49154032, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1349312  0.0211122 290.587  < 2e-16 ***
# cevd_event                   -0.0087740  0.0100578  -0.872  0.38301
# dias_bp_ave                   0.0010458  0.0001357   7.706 1.30e-14 ***
# sys_bp_ave                   -0.0016907  0.0002391  -7.072 1.53e-12 ***
# white_yes                    -0.0810580  0.0077226 -10.496  < 2e-16 ***
# male                         -0.1484155  0.0032347 -45.882  < 2e-16 ***
# alc_freq_filter              -0.0088974  0.0023474  -3.790  0.00015 ***
# age_i0                        0.0003896  0.0002482   1.570  0.11648
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + age_i0 + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + age_i0 +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_1,
#     init.theta = 10.1736848, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1442679  0.0253836 242.056  < 2e-16 ***
# cevd_event                   -0.0045865  0.0097565  -0.470 0.638285
# dias_bp_ave                   0.0010317  0.0001528   6.751 1.47e-11 ***
# sys_bp_ave                   -0.0015244  0.0002674  -5.702 1.19e-08 ***
# white_yes                    -0.0539076  0.0108848  -4.953 7.32e-07 ***
# male                         -0.1217613  0.0037002 -32.906  < 2e-16 ***
# alc_freq_filter               0.0010789  0.0025972   0.415 0.677835
# age_i0                       -0.0008328  0.0002889  -2.882 0.003951 **
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event *smok_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + male + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event * smok_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 10.3400209, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.132e+00  1.612e-02 380.337  < 2e-16 ***
# cevd_event                   -6.181e-03  1.009e-02  -0.613   0.5402
# smok_filter                   1.422e-02  2.403e-03   5.919 3.24e-09 ***
# dias_bp_ave                   1.043e-03  1.015e-04  10.280  < 2e-16 ***
# sys_bp_ave                   -1.606e-03  1.782e-04  -9.011  < 2e-16 ***
# white_yes                    -7.363e-02  6.301e-03 -11.686  < 2e-16 ***
# age_i0                       -8.347e-05  1.882e-04  -0.443   0.6575
# alc_freq_filter              -4.376e-03  1.740e-03  -2.515   0.0119 *
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + male +  +dias_bp_ave+ sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + male + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi +
#     full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_0,
#     init.theta = 1.60345694, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9225444  0.0542627  90.717  < 2e-16 ***
# cevd_event                   -0.0046339  0.0258606  -0.179  0.85779
# male                          0.4276166  0.0082914  51.574  < 2e-16 ***
# dias_bp_ave                   0.0010640  0.0003489   3.050  0.00229 **
# sys_bp_ave                   -0.0010460  0.0006144  -1.703  0.08865 .
# white_yes                     0.0864131  0.0199114   4.340 1.43e-05 ***
# alc_freq_filter               0.0674373  0.0060277  11.188  < 2e-16 ***
# age_i0                       -0.0076173  0.0006371 -11.955  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + male +  +dias_bp_ave+ sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_smoking_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + male + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + age_i0 + bmi +
#     full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter + dep_diag_yes, data = data_smoking_1,
#     init.theta = 1.402667233, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.119e+00  6.855e-02  74.671  < 2e-16 ***
# cevd_event                   -6.882e-02  2.638e-02  -2.608   0.0091 **
# male                          4.374e-01  9.987e-03  43.794  < 2e-16 ***
# dias_bp_ave                   4.766e-04  4.130e-04   1.154   0.2485
# sys_bp_ave                   -2.697e-05  7.223e-04  -0.037   0.9702
# white_yes                     8.670e-03  2.940e-02   0.295   0.7681
# alc_freq_filter               7.057e-02  7.014e-03  10.061  < 2e-16 ***
# age_i0                       -1.059e-02  7.795e-04 -13.583  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event * smok_filter + age_i0 +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + male + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event * smok_filter + age_i0 +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 1.510103631, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9991661  0.0423546 118.031  < 2e-16 ***
# cevd_event                    0.0043710  0.0265136   0.165 0.869054
# smok_filter                  -0.0083006  0.0063088  -1.316 0.188269
# age_i0                       -0.0088429  0.0004939 -17.903  < 2e-16 ***
# dias_bp_ave                   0.0007933  0.0002667   2.974 0.002937 **
# sys_bp_ave                   -0.0005746  0.0004682  -1.227 0.219698
# white_yes                     0.0592221  0.0165852   3.571 0.000356 ***
# ...

# %%
#create bmi subgroups
data_bmi_0 <- data[data$bmi_filter == 0, ]
data_bmi_1 <- data[data$bmi_filter == 1, ]

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + age_i0 + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_0,
#     init.theta = 1.315316053, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.0913494  0.0604696  67.660  < 2e-16 ***
# cevd_event                   -0.0228413  0.0251303  -0.909  0.36340
# dias_bp_ave                   0.0012182  0.0003747   3.251  0.00115 **
# sys_bp_ave                   -0.0041828  0.0006456  -6.479 9.26e-11 ***
# white_yes                     0.0628896  0.0229174   2.744  0.00607 **
# male                          0.4761346  0.0090245  52.760  < 2e-16 ***
# alc_freq_filter               0.0956759  0.0065298  14.652  < 2e-16 ***
# smok_filter                  -0.0164889  0.0088227  -1.869  0.06164 .
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + age_i0 + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_1,
#     init.theta = 1.749757988, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.1585386  0.0565930  73.482  < 2e-16 ***
# cevd_event                   -0.0624882  0.0274780  -2.274  0.02296 *
# dias_bp_ave                   0.0008014  0.0003826   2.095  0.03620 *
# sys_bp_ave                   -0.0021386  0.0006744  -3.171  0.00152 **
# white_yes                     0.0431064  0.0243552   1.770  0.07674 .
# male                          0.3644082  0.0092067  39.581  < 2e-16 ***
# alc_freq_filter               0.0671231  0.0063636  10.548  < 2e-16 ***
# smok_filter                  -0.0246471  0.0088201  -2.794  0.00520 **
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event *bmi_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  + alc_freq_filter + age_i0 + smok_filter + full_screen_time + employ_status_array_filter_1 + comorb_sum +dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event * bmi_filter + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + age_i0 + smok_filter +
#     full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 1.401271645,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   3.788e+00  4.331e-02  87.476  < 2e-16 ***
# cevd_event                    6.261e-05  2.427e-02   0.003    0.998
# bmi_filter                    1.517e-01  6.791e-03  22.333  < 2e-16 ***
# dias_bp_ave                   2.235e-03  2.755e-04   8.112 4.98e-16 ***
# sys_bp_ave                   -2.167e-03  4.795e-04  -4.520 6.19e-06 ***
# white_yes                     5.648e-02  1.717e-02   3.289    0.001 **
# alc_freq_filter               1.297e-01  4.660e-03  27.843  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter + smok_filter + age_i0 + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_0,
#     init.theta = 9.63271949, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0480630  0.0222794 271.464  < 2e-16 ***
# cevd_event                   -0.0063328  0.0092503  -0.685 0.493592
# dias_bp_ave                   0.0011067  0.0001379   8.023 1.03e-15 ***
# sys_bp_ave                   -0.0023573  0.0002378  -9.914  < 2e-16 ***
# white_yes                    -0.0852145  0.0084202 -10.120  < 2e-16 ***
# male                         -0.1251327  0.0033255 -37.628  < 2e-16 ***
# alc_freq_filter               0.0025732  0.0024054   1.070 0.284737
# smok_filter                   0.0156471  0.0032509   4.813 1.49e-06 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq  +  smok_filter + age_i0  + full_screen_time + employ_status_array_filter_1 + comorb_sum_filter, data = data_bmi_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum_filter, data = data_bmi_1, init.theta = 11.32745236,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.8783076  0.0230178 255.381  < 2e-16 ***
# cevd_event                   -0.0088503  0.0107563  -0.823   0.4106
# dias_bp_ave                   0.0010682  0.0001499   7.125 1.04e-12 ***
# sys_bp_ave                   -0.0018483  0.0002645  -6.987 2.81e-12 ***
# white_yes                    -0.0555340  0.0095705  -5.803 6.53e-09 ***
# male                         -0.1537938  0.0036157 -42.535  < 2e-16 ***
# alc_freq                      0.0049498  0.0012212   4.053 5.05e-05 ***
# smok_filter                   0.0085284  0.0034491   2.473   0.0134 *
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event *bmi_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + male + smok_filter + full_screen_time + employ_status_array_filter_1 + comorb_sum + dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event * bmi_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 10.29105611, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.969e+00  1.602e-02 372.677  < 2e-16 ***
# cevd_event                   -1.219e-02  8.931e-03  -1.365    0.172
# bmi_filter                    3.469e-02  2.520e-03  13.769  < 2e-16 ***
# dias_bp_ave                   1.095e-03  1.017e-04  10.770  < 2e-16 ***
# sys_bp_ave                   -2.106e-03  1.769e-04 -11.904  < 2e-16 ***
# white_yes                    -7.505e-02  6.315e-03 -11.885  < 2e-16 ***
# age_i0                        6.318e-07  1.888e-04   0.003    0.997
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter +age_i0 + full_screen_time + employ_status_array_filter_1 + comorb_sum_filter, data = data_bmi_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum_filter, data = data_bmi_0, init.theta = 29.11804635,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.248e+00  1.291e-02 484.034  < 2e-16 ***
# cevd_event                    1.388e-02  5.358e-03   2.590  0.00959 **
# dias_bp_ave                  -5.277e-04  7.994e-05  -6.602 4.06e-11 ***
# sys_bp_ave                    1.068e-03  1.380e-04   7.738 1.01e-14 ***
# white_yes                     1.569e-02  4.885e-03   3.211  0.00132 **
# male                          4.420e-02  1.921e-03  23.008  < 2e-16 ***
# alc_freq_filter              -2.094e-03  1.391e-03  -1.506  0.13204
# smok_filter                  -5.465e-03  1.883e-03  -2.902  0.00370 **
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter+age_i0 + full_screen_time + employ_status_array_filter_1 + comorb_sum_filter, data = data_bmi_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum_filter, data = data_bmi_1, init.theta = 28.25226109,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.257e+00  1.413e-02 442.801  < 2e-16 ***
# cevd_event                    7.271e-03  6.862e-03   1.060 0.289344
# dias_bp_ave                  -6.437e-04  9.573e-05  -6.724 1.76e-11 ***
# sys_bp_ave                    8.343e-04  1.688e-04   4.942 7.74e-07 ***
# white_yes                    -1.996e-03  6.085e-03  -0.328 0.742948
# male                          7.170e-02  2.304e-03  31.116  < 2e-16 ***
# alc_freq_filter               5.656e-03  1.590e-03   3.558 0.000374 ***
# smok_filter                  -2.994e-03  2.203e-03  -1.359 0.174108
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event *bmi_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + alc_freq_filter + male + smok_filter + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * bmi_filter + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + alc_freq_filter + male +
#     smok_filter + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 28.72976644, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.266e+00  9.667e-03 648.134  < 2e-16 ***
# cevd_event                    1.408e-02  5.378e-03   2.619 0.008819 **
# bmi_filter                   -3.849e-02  1.521e-03 -25.307  < 2e-16 ***
# dias_bp_ave                  -5.760e-04  6.138e-05  -9.384  < 2e-16 ***
# sys_bp_ave                    9.605e-04  1.067e-04   8.999  < 2e-16 ***
# white_yes                     8.736e-03  3.813e-03   2.291 0.021968 *
# age_i0                       -4.084e-04  1.139e-04  -3.586 0.000336 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + male +  +dias_bp_ave+ sys_bp_ave + white_yes  + alc_freq_filter  +  smok_filter + age_i0 + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + male + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_0,
#     init.theta = 42.86622767, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.154e+00  1.081e-02 569.267  < 2e-16 ***
# cevd_event                   -8.342e-03  4.484e-03  -1.860   0.0629 .
# male                         -1.168e-02  1.613e-03  -7.240 4.49e-13 ***
# dias_bp_ave                  -1.345e-04  6.690e-05  -2.011   0.0443 *
# sys_bp_ave                    4.590e-04  1.153e-04   3.981 6.87e-05 ***
# white_yes                     2.737e-02  4.093e-03   6.688 2.26e-11 ***
# alc_freq_filter              -6.380e-03  1.167e-03  -5.468 4.54e-08 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter + age_i0  + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_bmi_1,
#     init.theta = 48.32406625, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.188e+00  1.104e-02 560.630  < 2e-16 ***
# cevd_event                    3.065e-03  5.346e-03   0.573  0.56642
# dias_bp_ave                  -8.210e-05  7.455e-05  -1.101  0.27076
# sys_bp_ave                    5.216e-04  1.314e-04   3.969 7.23e-05 ***
# white_yes                     3.246e-02  4.748e-03   6.837 8.07e-12 ***
# male                         -1.702e-02  1.799e-03  -9.458  < 2e-16 ***
# alc_freq_filter              -6.715e-03  1.240e-03  -5.414 6.16e-08 ***
# smok_filter                   1.195e-03  1.720e-03   0.695  0.48693
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event *bmi_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + alc_freq_filter + male + smok_filter + full_screen_time + employ_status_array_filter_1 + comorb_sum +dep_diag_yes + gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event * bmi_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 45.04432366, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.169e+00  7.848e-03 786.125  < 2e-16 ***
# cevd_event                   -6.804e-03  4.369e-03  -1.557  0.11937
# bmi_filter                    4.007e-03  1.234e-03   3.247  0.00117 **
# dias_bp_ave                  -1.089e-04  4.980e-05  -2.186  0.02880 *
# sys_bp_ave                    4.651e-04  8.662e-05   5.370 7.89e-08 ***
# white_yes                     2.948e-02  3.099e-03   9.514  < 2e-16 ***
# age_i0                        1.035e-03  9.246e-05  11.193  < 2e-16 ***
# ...

# %%
#create employment status subgroups
data_employ_0 <- data[data$employ_status_array_filter_1 == 0, ]
data_employ_1 <- data[data$employ_status_array_filter_1 == 1, ]

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0,
#     init.theta = 47.95411117, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.227e+00  1.462e-02 425.899  < 2e-16 ***
# cevd_event                   -3.896e-03  4.576e-03  -0.851 0.394536
# dias_bp_ave                  -1.416e-04  7.534e-05  -1.879 0.060228 .
# sys_bp_ave                    7.157e-04  1.395e-04   5.131 2.88e-07 ***
# white_yes                     1.908e-02  6.489e-03   2.940 0.003284 **
# male                         -8.049e-04  2.068e-03  -0.389 0.697139
# alc_freq_filter              -8.741e-03  1.397e-03  -6.256 3.94e-10 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1,
#     init.theta = 43.84038518, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.172e+00  8.924e-03 691.702  < 2e-16 ***
# cevd_event                   -3.651e-03  5.082e-03  -0.718 0.472479
# dias_bp_ave                  -5.604e-05  6.608e-05  -0.848 0.396384
# sys_bp_ave                    4.050e-04  1.127e-04   3.593 0.000327 ***
# white_yes                     3.246e-02  3.545e-03   9.157  < 2e-16 ***
# male                         -1.968e-02  1.467e-03 -13.413  < 2e-16 ***
# alc_freq_filter              -6.120e-03  1.076e-03  -5.688 1.29e-08 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event *employ_status_array_filter_1 +  +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + alc_freq_filter + male + smok_filter + full_screen_time + bmi + comorb_sum +dep_diag_yes+gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event * employ_status_array_filter_1 +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + full_screen_time + bmi + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 45.0702104,
#     link = log)
#
# Coefficients:
#                                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)                              6.192e+00  7.922e-03 781.617  < 2e-16
# cevd_event                              -4.605e-03  4.686e-03  -0.983  0.32578
# employ_status_array_filter_1            -1.318e-02  1.463e-03  -9.012  < 2e-16
# dias_bp_ave                             -1.166e-04  4.980e-05  -2.341  0.01924
# sys_bp_ave                               5.523e-04  8.745e-05   6.315 2.70e-10
# white_yes                                2.973e-02  3.098e-03   9.595  < 2e-16
# age_i0                                   1.028e-03  9.240e-05  11.122  < 2e-16
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0,
#     init.theta = 31.73703694, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.858e+00  1.772e-02 330.680  < 2e-16 ***
# cevd_event                    1.033e-02  5.537e-03   1.866 0.062102 .
# dias_bp_ave                  -5.177e-04  9.124e-05  -5.673  1.4e-08 ***
# sys_bp_ave                    6.208e-04  1.689e-04   3.676 0.000237 ***
# white_yes                     1.491e-02  7.856e-03   1.898 0.057724 .
# male                          4.548e-02  2.504e-03  18.165  < 2e-16 ***
# alc_freq_filter               2.030e-03  1.692e-03   1.200 0.230289
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1,
#     init.theta = 28.23554009, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.197e+00  1.094e-02 566.463  < 2e-16 ***
# cevd_event                    4.826e-03  6.231e-03   0.774  0.43865
# dias_bp_ave                  -6.394e-04  8.105e-05  -7.888 3.06e-15 ***
# sys_bp_ave                    6.010e-04  1.382e-04   4.348 1.38e-05 ***
# white_yes                     3.577e-03  4.342e-03   0.824  0.41002
# male                          5.975e-02  1.799e-03  33.221  < 2e-16 ***
# alc_freq_filter               6.674e-03  1.320e-03   5.058 4.25e-07 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event *employ_status_array_filter_1 +  +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + alc_freq_filter + male + smok_filter + full_screen_time + bmi + comorb_sum +dep_diag_yes+gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * employ_status_array_filter_1 +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + full_screen_time + bmi + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 29.09202632,
#     link = log)
#
# Coefficients:
#                                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)                              6.098e+00  9.703e-03 628.507  < 2e-16
# cevd_event                               1.884e-02  5.744e-03   3.281  0.00103
# employ_status_array_filter_1             2.925e-02  1.793e-03  16.316  < 2e-16
# dias_bp_ave                             -5.313e-04  6.104e-05  -8.705  < 2e-16
# sys_bp_ave                               4.946e-04  1.072e-04   4.616 3.92e-06
# white_yes                                7.036e-03  3.791e-03   1.856  0.06346
# age_i0                                  -3.266e-04  1.132e-04  -2.885  0.00391
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0,
#     init.theta = 11.15283195, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.4184929  0.0295518 217.194  < 2e-16 ***
# cevd_event                   -0.0062203  0.0092616  -0.672   0.5018
# dias_bp_ave                   0.0010402  0.0001524   6.826 8.74e-12 ***
# sys_bp_ave                   -0.0020486  0.0002822  -7.260 3.88e-13 ***
# white_yes                    -0.0748551  0.0131074  -5.711 1.12e-08 ***
# male                         -0.1445116  0.0041861 -34.522  < 2e-16 ***
# alc_freq_filter               0.0045074  0.0028260   1.595   0.1107
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1,
#     init.theta = 10.05731298, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0172649  0.0181829 330.929  < 2e-16 ***
# cevd_event                   -0.0017738  0.0103631  -0.171   0.8641
# dias_bp_ave                   0.0011044  0.0001347   8.200 2.41e-16 ***
# sys_bp_ave                   -0.0015161  0.0002298  -6.598 4.16e-11 ***
# white_yes                    -0.0704019  0.0072132  -9.760  < 2e-16 ***
# male                         -0.1314266  0.0029909 -43.943  < 2e-16 ***
# alc_freq_filter              -0.0098646  0.0021934  -4.497 6.88e-06 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event *employ_status_array_filter_1 +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + alc_freq_filter + male + smok_filter + full_screen_time + bmi + comorb_sum +dep_diag_yes+gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event * employ_status_array_filter_1 +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + full_screen_time + bmi + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 10.34038652,
#     link = log)
#
# Coefficients:
#                                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)                              6.133e+00  1.613e-02 380.138  < 2e-16
# cevd_event                              -1.720e-02  9.560e-03  -1.799   0.0720
# employ_status_array_filter_1            -2.297e-02  2.981e-03  -7.706 1.30e-14
# dias_bp_ave                              1.043e-03  1.015e-04  10.282  < 2e-16
# sys_bp_ave                              -1.607e-03  1.782e-04  -9.015  < 2e-16
# white_yes                               -7.366e-02  6.301e-03 -11.691  < 2e-16
# age_i0                                  -8.941e-05  1.883e-04  -0.475   0.6349
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_0,
#     init.theta = 1.382530686, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.6452924  0.0842041  67.043  < 2e-16 ***
# cevd_event                   -0.0633609  0.0264089  -2.399  0.01643 *
# dias_bp_ave                   0.0007798  0.0004344   1.795  0.07264 .
# sys_bp_ave                   -0.0005127  0.0008043  -0.638  0.52378
# white_yes                     0.0977202  0.0374894   2.607  0.00914 **
# male                          0.5227137  0.0119003  43.924  < 2e-16 ***
# alc_freq_filter               0.0697920  0.0080472   8.673  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_employ_1,
#     init.theta = 1.585619004, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.7860475  0.0459913 104.064  < 2e-16 ***
# cevd_event                   -0.0034714  0.0261995  -0.132 0.894591
# dias_bp_ave                   0.0011813  0.0003406   3.468 0.000524 ***
# sys_bp_ave                   -0.0011317  0.0005809  -1.948 0.051383 .
# white_yes                     0.0520306  0.0182787   2.847 0.004420 **
# male                          0.3937113  0.0075531  52.126  < 2e-16 ***
# alc_freq_filter               0.0663280  0.0055437  11.965  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event *employ_status_array_filter_1 + age_i0 +  +dias_bp_ave+ sys_bp_ave + white_yes +  alc_freq_filter + male + smok_filter + full_screen_time+ bmi + comorb_sum +dep_diag_yes +gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event * employ_status_array_filter_1 +
#     age_i0 + +dias_bp_ave + sys_bp_ave + white_yes + alc_freq_filter +
#     male + smok_filter + full_screen_time + bmi + comorb_sum +
#     dep_diag_yes + gov_assistance_filter, data = data, init.theta = 1.510120177,
#     link = log)
#
# Coefficients:
#                                           Estimate Std. Error z value Pr(>|z|)
# (Intercept)                              5.0034313  0.0423842 118.050  < 2e-16
# cevd_event                              -0.0815188  0.0251891  -3.236 0.001211
# employ_status_array_filter_1            -0.0251764  0.0078318  -3.215 0.001306
# age_i0                                  -0.0088552  0.0004940 -17.926  < 2e-16
# dias_bp_ave                              0.0007980  0.0002667   2.992 0.002774
# sys_bp_ave                              -0.0005828  0.0004682  -1.245 0.213259
# white_yes                                0.0589854  0.0165847   3.557 0.000376
# ...

# %%
#create screen time daily subgroups
data$full_screen_time_filter <- ifelse(data$full_screen_time < 2, 1, 0)
data_screen_0 <- data[data$full_screen_time_filter == 0, ]
data_screen_1 <- data[data$full_screen_time_filter == 1, ]

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + male + alc_freq_filter  +  +dias_bp_ave+ sys_bp_ave + white_yes + smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + male + alc_freq_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + smok_filter + age_i0 +
#     bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0,
#     init.theta = 1.459226227, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.8754212  0.0464078 105.056  < 2e-16 ***
# cevd_event                   -0.0360981  0.0196905  -1.833  0.06676 .
# male                          0.4284789  0.0068889  62.199  < 2e-16 ***
# alc_freq_filter               0.0738152  0.0049789  14.826  < 2e-16 ***
# dias_bp_ave                   0.0007250  0.0002883   2.515  0.01192 *
# sys_bp_ave                   -0.0003943  0.0005074  -0.777  0.43718
# white_yes                     0.0776302  0.0179898   4.315 1.59e-05 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1,
#     init.theta = 1.852118487, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.8381844  0.1044262  46.331  < 2e-16 ***
# cevd_event                   -0.0315848  0.0532725  -0.593  0.55325
# dias_bp_ave                   0.0023111  0.0007127   3.243  0.00118 **
# sys_bp_ave                   -0.0034320  0.0012284  -2.794  0.00521 **
# white_yes                     0.1039336  0.0427134   2.433  0.01496 *
# male                          0.3548834  0.0165880  21.394  < 2e-16 ***
# alc_freq_filter               0.0637877  0.0114536   5.569 2.56e-08 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event *full_screen_time_filter +  +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + alc_freq_filter + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum +dep_diag_yes+gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event * full_screen_time_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + employ_status_array_filter_1 + bmi +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 1.502492011, link = log)
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         4.8516158  0.0426017 113.883  < 2e-16 ***
# cevd_event                         -0.0377991  0.0193987  -1.949  0.05135 .
# full_screen_time_filter             0.1388731  0.0091942  15.104  < 2e-16 ***
# dias_bp_ave                         0.0008851  0.0002673   3.311  0.00093 ***
# sys_bp_ave                         -0.0006942  0.0004692  -1.480  0.13900
# white_yes                           0.0803063  0.0166049   4.836 1.32e-06 ***
# age_i0                             -0.0085980  0.0004952 -17.361  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0,
#     init.theta = 10.0664282, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0801194  0.0175993 345.475  < 2e-16 ***
# cevd_event                   -0.0069095  0.0074615  -0.926 0.354439
# dias_bp_ave                   0.0010632  0.0001093   9.728  < 2e-16 ***
# sys_bp_ave                   -0.0016847  0.0001924  -8.755  < 2e-16 ***
# white_yes                    -0.0619964  0.0068093  -9.105  < 2e-16 ***
# male                         -0.1451128  0.0026166 -55.458  < 2e-16 ***
# alc_freq_filter               0.0005782  0.0018891   0.306 0.759570
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1,
#     init.theta = 11.30568926, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0352316  0.0420926 143.380  < 2e-16 ***
# cevd_event                   -0.0033689  0.0214817  -0.157 0.875383
# dias_bp_ave                   0.0013749  0.0002874   4.784 1.72e-06 ***
# sys_bp_ave                   -0.0019689  0.0004956  -3.973 7.10e-05 ***
# white_yes                    -0.0639006  0.0171769  -3.720 0.000199 ***
# male                         -0.1383568  0.0067113 -20.615  < 2e-16 ***
# alc_freq_filter              -0.0233297  0.0046220  -5.048 4.47e-07 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event *full_screen_time_filter +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + alc_freq_filter + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum +dep_diag_yes +gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event * full_screen_time_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + employ_status_array_filter_1 + bmi +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 10.19883409, link = log)
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         6.063e+00  1.629e-02 372.258  < 2e-16 ***
# cevd_event                         -9.592e-03  7.408e-03  -1.295    0.195
# full_screen_time_filter             5.707e-02  3.525e-03  16.191  < 2e-16 ***
# dias_bp_ave                         1.094e-03  1.022e-04  10.704  < 2e-16 ***
# sys_bp_ave                         -1.686e-03  1.794e-04  -9.401  < 2e-16 ***
# white_yes                          -6.306e-02  6.335e-03  -9.954  < 2e-16 ***
# age_i0                              7.718e-06  1.896e-04   0.041    0.968
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0,
#     init.theta = 29.05502707, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1281150  0.0104498 586.434  < 2e-16 ***
# cevd_event                    0.0110477  0.0044260   2.496   0.0126 *
# dias_bp_ave                  -0.0005270  0.0000649  -8.120 4.66e-16 ***
# sys_bp_ave                    0.0005188  0.0001142   4.542 5.58e-06 ***
# white_yes                     0.0005132  0.0040452   0.127   0.8991
# male                          0.0601736  0.0015527  38.755  < 2e-16 ***
# alc_freq_filter               0.0028259  0.0011216   2.519   0.0118 *
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1,
#     init.theta = 26.96776653, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1312210  0.0274603 223.275  < 2e-16 ***
# cevd_event                   -0.0041580  0.0140164  -0.297  0.76673
# dias_bp_ave                  -0.0008579  0.0001876  -4.573  4.8e-06 ***
# sys_bp_ave                    0.0009055  0.0003233   2.801  0.00510 **
# white_yes                     0.0036765  0.0112125   0.328  0.74299
# male                          0.0628568  0.0043717  14.378  < 2e-16 ***
# alc_freq_filter               0.0090380  0.0030154   2.997  0.00272 **
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event *full_screen_time_filter +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + alc_freq_filter + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum +dep_diag_yes +gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * full_screen_time_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + employ_status_array_filter_1 + bmi +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 28.7291961, link = log)
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         6.1338075  0.0097868 626.746  < 2e-16 ***
# cevd_event                          0.0123707  0.0044458   2.783 0.005393 **
# full_screen_time_filter            -0.0241102  0.0021215 -11.365  < 2e-16 ***
# dias_bp_ave                        -0.0005603  0.0000614  -9.125  < 2e-16 ***
# sys_bp_ave                          0.0005487  0.0001078   5.091 3.56e-07 ***
# white_yes                           0.0012638  0.0038090   0.332 0.740050
# age_i0                             -0.0003670  0.0001139  -3.223 0.001269 **
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_0,
#     init.theta = 44.22224192, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.210e+00  8.602e-03 721.911  < 2e-16 ***
# cevd_event                   -5.149e-03  3.643e-03  -1.413  0.15753
# dias_bp_ave                  -1.147e-04  5.339e-05  -2.148  0.03168 *
# sys_bp_ave                    5.382e-04  9.400e-05   5.725 1.03e-08 ***
# white_yes                     2.851e-02  3.333e-03   8.555  < 2e-16 ***
# male                         -1.332e-02  1.278e-03 -10.426  < 2e-16 ***
# alc_freq_filter              -8.194e-03  9.229e-04  -8.879  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time_filter + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time_filter + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_screen_1,
#     init.theta = 52.37116307, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1717300  0.0201913 305.662  < 2e-16 ***
# cevd_event                    0.0096424  0.0102938   0.937 0.348901
# dias_bp_ave                  -0.0002519  0.0001378  -1.827 0.067672 .
# sys_bp_ave                    0.0007270  0.0002376   3.059 0.002218 **
# white_yes                     0.0297430  0.0082548   3.603 0.000314 ***
# male                         -0.0147101  0.0032162  -4.574 4.79e-06 ***
# alc_freq_filter               0.0001723  0.0022163   0.078 0.938042
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event *full_screen_time_filter +  +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + alc_freq_filter + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum +dep_diag_yes +gov_assistance_filter, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event * full_screen_time_filter +
#     +dias_bp_ave + sys_bp_ave + white_yes + age_i0 + alc_freq_filter +
#     male + smok_filter + employ_status_array_filter_1 + bmi +
#     comorb_sum + dep_diag_yes + gov_assistance_filter, data = data,
#     init.theta = 45.12037356, link = log)
#
# Coefficients:
#                                      Estimate Std. Error z value Pr(>|z|)
# (Intercept)                         6.208e+00  7.939e-03 782.017  < 2e-16 ***
# cevd_event                         -4.979e-03  3.606e-03  -1.381 0.167419
# full_screen_time_filter            -2.248e-02  1.720e-03 -13.065  < 2e-16 ***
# dias_bp_ave                        -1.274e-04  4.978e-05  -2.560 0.010477 *
# sys_bp_ave                          5.550e-04  8.740e-05   6.351 2.15e-10 ***
# white_yes                           2.869e-02  3.093e-03   9.277  < 2e-16 ***
# age_i0                              9.932e-04  9.238e-05  10.752  < 2e-16 ***
# ...

# %%
#if you want to look into alcohol frequency
#data$alc_freq_table4 <- ifelse(data$alc_freq < 3, 1, 0)
#data_alc_0 <- data[data$alc_freq_table4 == 0, ]
#data_alc_1 <- data[data$alc_freq_table4 == 1, ]

# %%
#

# %%
#extra subgroup analysis on depression

# %%
#

# %%
#create depression subgroups
data_dep_0 <- data[data$dep_diag_yes == 0, ]
data_dep_1 <- data[data$dep_diag_yes == 1, ]

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0,
#     init.theta = 45.54605054, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.187e+00  8.256e-03 749.434  < 2e-16 ***
# cevd_event                   -3.051e-03  3.599e-03  -0.848   0.3965
# dias_bp_ave                  -9.960e-05  5.182e-05  -1.922   0.0546 .
# sys_bp_ave                    5.362e-04  9.122e-05   5.878 4.15e-09 ***
# white_yes                     3.048e-02  3.183e-03   9.574  < 2e-16 ***
# male                         -1.476e-02  1.239e-03 -11.913  < 2e-16 ***
# alc_freq_filter              -6.839e-03  8.943e-04  -7.648 2.05e-14 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1,
#     init.theta = 40.89393334, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.2628492  0.0280522 223.257  < 2e-16 ***
# cevd_event                   -0.0113116  0.0113821  -0.994  0.32032
# dias_bp_ave                  -0.0003012  0.0001788  -1.684  0.09218 .
# sys_bp_ave                    0.0007183  0.0003057   2.349  0.01880 *
# white_yes                     0.0161836  0.0130808   1.237  0.21601
# male                         -0.0041390  0.0044258  -0.935  0.34969
# alc_freq_filter              -0.0079247  0.0028761  -2.755  0.00586 **
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event * dep_diag_yes +  +dias_bp_ave+ sys_bp_ave + white_yes  +alc_freq_filter + full_screen_time + age_i0  + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum + gov_assistance_filter , data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event * dep_diag_yes +
#     +dias_bp_ave + sys_bp_ave + white_yes + alc_freq_filter +
#     full_screen_time + age_i0 + male + smok_filter + employ_status_array_filter_1 +
#     bmi + comorb_sum + gov_assistance_filter, data = data, init.theta = 45.07085526,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.192e+00  7.916e-03 782.175  < 2e-16 ***
# cevd_event                   -2.708e-03  3.614e-03  -0.750  0.45353
# dep_diag_yes                  2.119e-02  2.041e-03  10.384  < 2e-16 ***
# dias_bp_ave                  -1.168e-04  4.981e-05  -2.346  0.01897 *
# sys_bp_ave                    5.529e-04  8.745e-05   6.323 2.57e-10 ***
# white_yes                     2.974e-02  3.098e-03   9.599  < 2e-16 ***
# alc_freq_filter              -6.937e-03  8.540e-04  -8.122 4.57e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0,
#     init.theta = 29.33054786, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.097e+00  1.012e-02 602.375  < 2e-16 ***
# cevd_event                    9.415e-03  4.413e-03   2.134  0.03287 *
# dias_bp_ave                  -5.380e-04  6.356e-05  -8.464  < 2e-16 ***
# sys_bp_ave                    4.914e-04  1.119e-04   4.392 1.12e-05 ***
# white_yes                     5.753e-03  3.898e-03   1.476  0.14003
# male                          5.746e-02  1.519e-03  37.837  < 2e-16 ***
# alc_freq_filter               5.692e-03  1.097e-03   5.190 2.11e-07 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes+ male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1,
#     init.theta = 26.96333768, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1018399  0.0340944 178.969  < 2e-16 ***
# cevd_event                    0.0108992  0.0138262   0.788 0.430520
# dias_bp_ave                  -0.0004694  0.0002174  -2.159 0.030823 *
# sys_bp_ave                    0.0005408  0.0003716   1.455 0.145551
# white_yes                     0.0257175  0.0158959   1.618 0.105691
# male                          0.0435868  0.0053765   8.107 5.19e-16 ***
# alc_freq_filter              -0.0043571  0.0034956  -1.246 0.212599
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event * dep_diag_yes +  +dias_bp_ave+ sys_bp_ave + white_yes+ alc_freq_filter + full_screen_time + age_i0  + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum + gov_assistance_filter , data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event * dep_diag_yes +
#     +dias_bp_ave + sys_bp_ave + white_yes + alc_freq_filter +
#     full_screen_time + age_i0 + male + smok_filter + employ_status_array_filter_1 +
#     bmi + comorb_sum + gov_assistance_filter, data = data, init.theta = 29.08984213,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.099e+00  9.696e-03 629.033  < 2e-16 ***
# cevd_event                    9.199e-03  4.427e-03   2.078  0.03768 *
# dep_diag_yes                 -4.587e-03  2.502e-03  -1.833  0.06677 .
# dias_bp_ave                  -5.312e-04  6.104e-05  -8.703  < 2e-16 ***
# sys_bp_ave                    4.941e-04  1.072e-04   4.612 4.00e-06 ***
# white_yes                     7.022e-03  3.791e-03   1.852  0.06399 .
# alc_freq_filter               4.696e-03  1.046e-03   4.488 7.21e-06 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + male +  +dias_bp_ave+ sys_bp_ave + white_yes+ alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + male + +dias_bp_ave +
#     sys_bp_ave + white_yes + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0,
#     init.theta = 10.49569662, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1383686  0.0167738 365.949  < 2e-16 ***
# cevd_event                   -0.0080805  0.0073209  -1.104 0.269698
# male                         -0.1378556  0.0025186 -54.735  < 2e-16 ***
# dias_bp_ave                   0.0010159  0.0001053   9.644  < 2e-16 ***
# sys_bp_ave                   -0.0015486  0.0001855  -8.350  < 2e-16 ***
# white_yes                    -0.0727255  0.0064578 -11.262  < 2e-16 ***
# alc_freq_filter              -0.0062611  0.0018179  -3.444 0.000573 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1,
#     init.theta = 8.981920488, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0683843  0.0585538 103.638  < 2e-16 ***
# cevd_event                    0.0098268  0.0237643   0.414 0.679233
# dias_bp_ave                   0.0013347  0.0003733   3.575 0.000350 ***
# sys_bp_ave                   -0.0022059  0.0006384  -3.455 0.000549 ***
# white_yes                    -0.0836398  0.0272844  -3.065 0.002173 **
# male                         -0.1269555  0.0092466 -13.730  < 2e-16 ***
# alc_freq_filter               0.0126645  0.0060043   2.109 0.034923 *
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event * dep_diag_yes +  +dias_bp_ave+ sys_bp_ave + white_yes  +alc_freq_filter + full_screen_time + age_i0 + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum + gov_assistance_filter , data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event * dep_diag_yes +
#     +dias_bp_ave + sys_bp_ave + white_yes + alc_freq_filter +
#     full_screen_time + age_i0 + male + smok_filter + employ_status_array_filter_1 +
#     bmi + comorb_sum + gov_assistance_filter, data = data, init.theta = 10.34007906,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.132e+00  1.612e-02 380.346  < 2e-16 ***
# cevd_event                   -8.013e-03  7.368e-03  -1.088   0.2768
# dep_diag_yes                 -1.760e-02  4.162e-03  -4.229 2.35e-05 ***
# dias_bp_ave                   1.044e-03  1.015e-04  10.283  < 2e-16 ***
# sys_bp_ave                   -1.607e-03  1.782e-04  -9.016  < 2e-16 ***
# white_yes                    -7.365e-02  6.301e-03 -11.689  < 2e-16 ***
# alc_freq_filter              -4.368e-03  1.740e-03  -2.510   0.0121 *
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_0,
#     init.theta = 1.539159472, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9963413  0.0439593 113.658  < 2e-16 ***
# cevd_event                   -0.0310047  0.0191962  -1.615 0.106278
# dias_bp_ave                   0.0007211  0.0002762   2.611 0.009033 **
# sys_bp_ave                   -0.0005565  0.0004860  -1.145 0.252181
# white_yes                     0.0646993  0.0169602   3.815 0.000136 ***
# male                          0.4299181  0.0065909  65.229  < 2e-16 ***
# alc_freq_filter               0.0666611  0.0047619  13.999  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event +  +dias_bp_ave+ sys_bp_ave + white_yes  +male + alc_freq_filter  +  smok_filter + age_i0 +bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     age_i0 + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_dep_1,
#     init.theta = 1.253583841, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9269070  0.1577260  31.237  < 2e-16 ***
# cevd_event                   -0.1022399  0.0642329  -1.592   0.1115
# dias_bp_ave                   0.0017432  0.0010059   1.733   0.0831 .
# sys_bp_ave                   -0.0009881  0.0017201  -0.574   0.5657
# white_yes                    -0.0035789  0.0736480  -0.049   0.9612
# male                          0.4419176  0.0248109  17.811  < 2e-16 ***
# alc_freq_filter               0.0895379  0.0161552   5.542 2.98e-08 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event * dep_diag_yes +  +dias_bp_ave+ sys_bp_ave + white_yes  + alc_freq_filter + full_screen_time + age_i0 + male + smok_filter + employ_status_array_filter_1 + bmi + comorb_sum + gov_assistance_filter , data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
#Bonferroni-correction
alpha <- 0.05
cum_coef <- length(coef(m1)) 
alpha_mod <- alpha / cum_coef
ci <- confint(m1, level = 1 - alpha_mod)
exp(ci)
summary_m1 <- summary(m1)
adjusted_p_values <- summary_m1$coefficients[, "Pr(>|z|)"]
print(exp(ci))
print(adjusted_p_values)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event * dep_diag_yes +
#     +dias_bp_ave + sys_bp_ave + white_yes + alc_freq_filter +
#     full_screen_time + age_i0 + male + smok_filter + employ_status_array_filter_1 +
#     bmi + comorb_sum + gov_assistance_filter, data = data, init.theta = 1.510024412,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9994371  0.0423550 118.037  < 2e-16 ***
# cevd_event                   -0.0315348  0.0193572  -1.629 0.103293
# dep_diag_yes                 -0.0847779  0.0109627  -7.733 1.05e-14 ***
# dias_bp_ave                   0.0007941  0.0002667   2.977 0.002910 **
# sys_bp_ave                   -0.0005742  0.0004682  -1.226 0.220050
# white_yes                     0.0591568  0.0165853   3.567 0.000361 ***
# alc_freq_filter               0.0689928  0.0045695  15.099  < 2e-16 ***
# full_screen_time             -0.0369568  0.0014829 -24.922  < 2e-16 ***
# ...

# %%
#mediation analysis

# %%
modelz.0 <- lm(cevd_event ~ comorb_sum_filter, data)

# %%
summary(modelz.0)
# Out:
# Call:
# lm(formula = cevd_event ~ comorb_sum_filter, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05213 -0.03555 -0.01896 -0.01896  0.98104
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       0.0189569  0.0007535   25.16   <2e-16 ***
# comorb_sum_filter 0.0165883  0.0008279   20.04   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1649 on 76077 degrees of freedom
# Multiple R-squared:  0.00525,	Adjusted R-squared:  0.005237
# F-statistic: 401.5 on 1 and 76077 DF,  p-value: < 2.2e-16

# %%
modelz.M <- lm(pa_mv_convert ~ comorb_sum_filter, data)

# %%
summary(modelz.M)
# Out:
# Call:
# lm(formula = pa_mv_convert ~ comorb_sum_filter, data = data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -43.90 -24.91  -7.93  16.09 389.09
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)        43.8988     0.1574  278.94   <2e-16 ***
# comorb_sum_filter  -4.9845     0.1729  -28.83   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 34.45 on 76076 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.0108,	Adjusted R-squared:  0.01079
# F-statistic:   831 on 1 and 76076 DF,  p-value: < 2.2e-16

# %%
modelz.Y <- lm(cevd_event ~ comorb_sum_filter + pa_mv_convert, data)

# %%
summary(modelz.Y)
# Out:
# Call:
# lm(formula = cevd_event ~ comorb_sum_filter + pa_mv_convert,
#     data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05356 -0.03605 -0.02026 -0.01891  0.98887
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        2.080e-02  1.072e-03  19.413   <2e-16 ***
# comorb_sum_filter  1.638e-02  8.324e-04  19.679   <2e-16 ***
# pa_mv_convert     -4.207e-05  1.736e-05  -2.424   0.0154 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1649 on 76075 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.005328,	Adjusted R-squared:  0.005302
# F-statistic: 203.7 on 2 and 76075 DF,  p-value: < 2.2e-16
