# %%
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index as cindex

# %%
import pandas as pd

# %%
df = pd.read_csv("cevd_first_model.csv")
# Out:
# /tmp/ipykernel_249/2185196800.py:1: DtypeWarning: Columns (14,28,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("cevd_first_model.csv")

# %%
#mvpa analyses

# %%
df['pa_mv_convert_levels'] = df['pa_mv_convert'].apply(lambda x: 1 if x < 21.4286 else 0)
df['pa_sleep_convert_levels'] = df['pa_sleep_convert'].apply(lambda x: 1 if 419 < x < 541 else 0)

# %%
df2 = df.dropna(subset=['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'pa_mv_convert', 'dias_bp_ave', 'sys_bp_ave', 'white_yes', 'comorb_sum'])

# %%
len(df2)
# Out:
# 2141

# %%
df2['pa_mv_convert_levels'].head(4)
# Out:
# 23    0
# 33    1
# 52    1
# 89    1
# Name: pa_mv_convert_levels, dtype: int64

# %%
df2['pa_sleep_convert'].head(4)
# Out:
# 23    460.1808
# 33    619.7760
# 52    393.3648
# 89    667.9584
# Name: pa_sleep_convert, dtype: float64

# %%
df2 = df2.loc[:, ['cevd_event', 'cevd_t2e',  'pa_mv_convert']]
df2 = df2[['cevd_event', 'cevd_t2e', 'pa_mv_convert' ]]
#fulladjust_allcevd_data = pd.get_dummies(fulladjust_allcevd, columns=['alc_freq', 'smok_stat'])
cph = CoxPHFitter(penalizer=0.0001)
cph.fit(df2, duration_col='cevd_t2e', event_col='cevd_event') 
summary_df = cph.summary 
summary_df.style.format({'p': '{:.5f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb52f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb52f_level0_col0" class="col_heading level0 col0" >coef</th>
#       <th id="T_bb52f_level0_col1" class="col_heading level0 col1" >exp(coef)</th>
#       <th id="T_bb52f_level0_col2" class="col_heading level0 col2" >se(coef)</th>
#       <th id="T_bb52f_level0_col3" class="col_heading level0 col3" >coef lower 95%</th>
#       <th id="T_bb52f_level0_col4" class="col_heading level0 col4" >coef upper 95%</th>
#       <th id="T_bb52f_level0_col5" class="col_heading level0 col5" >exp(coef) lower 95%</th>
#       <th id="T_bb52f_level0_col6" class="col_heading level0 col6" >exp(coef) upper 95%</th>
#       <th id="T_bb52f_level0_col7" class="col_heading level0 col7" >cmp to</th>
#       <th id="T_bb52f_level0_col8" class="col_heading level0 col8" >z</th>
#       <th id="T_bb52f_level0_col9" class="col_heading level0 col9" >p</th>
# ...

# %%
df2 = df.dropna(subset=['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_mv_convert'])

# %%
df2 = df2.loc[:, ['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_mv_convert']]
df2 = df2[['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_mv_convert' ]]
#fulladjust_allcevd_data = pd.get_dummies(fulladjust_allcevd, columns=['alc_freq', 'smok_stat'])
cph = CoxPHFitter(penalizer=0.0001)
cph.fit(df2, duration_col='cevd_t2e', event_col='cevd_event') 
summary_df = cph.summary 
summary_df.style.format({'p': '{:.5f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4275">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4275_level0_col0" class="col_heading level0 col0" >coef</th>
#       <th id="T_f4275_level0_col1" class="col_heading level0 col1" >exp(coef)</th>
#       <th id="T_f4275_level0_col2" class="col_heading level0 col2" >se(coef)</th>
#       <th id="T_f4275_level0_col3" class="col_heading level0 col3" >coef lower 95%</th>
#       <th id="T_f4275_level0_col4" class="col_heading level0 col4" >coef upper 95%</th>
#       <th id="T_f4275_level0_col5" class="col_heading level0 col5" >exp(coef) lower 95%</th>
#       <th id="T_f4275_level0_col6" class="col_heading level0 col6" >exp(coef) upper 95%</th>
#       <th id="T_f4275_level0_col7" class="col_heading level0 col7" >cmp to</th>
#       <th id="T_f4275_level0_col8" class="col_heading level0 col8" >z</th>
#       <th id="T_f4275_level0_col9" class="col_heading level0 col9" >p</th>
# ...

# %%
df3 = df.dropna(subset=['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_mv_convert'])
df3['pa_mv_convert_levels1'] = df3['pa_mv_convert'].apply(lambda x: 0 if x < 21.4286 else 1)
# Out:
# /tmp/ipykernel_249/933911004.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['pa_mv_convert_levels1'] = df3['pa_mv_convert'].apply(lambda x: 0 if x < 21.4286 else 1)

# %%
df3 = df3.loc[:, ['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_mv_convert_levels1']]
df3 = df3[['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_mv_convert_levels1' ]]
#fulladjust_allcevd_data = pd.get_dummies(fulladjust_allcevd, columns=['alc_freq', 'smok_stat'])
cph = CoxPHFitter(penalizer=0.0001)
cph.fit(df3, duration_col='cevd_t2e', event_col='cevd_event') 
summary_df = cph.summary 
summary_df.style.format({'p': '{:.5f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd945">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd945_level0_col0" class="col_heading level0 col0" >coef</th>
#       <th id="T_fd945_level0_col1" class="col_heading level0 col1" >exp(coef)</th>
#       <th id="T_fd945_level0_col2" class="col_heading level0 col2" >se(coef)</th>
#       <th id="T_fd945_level0_col3" class="col_heading level0 col3" >coef lower 95%</th>
#       <th id="T_fd945_level0_col4" class="col_heading level0 col4" >coef upper 95%</th>
#       <th id="T_fd945_level0_col5" class="col_heading level0 col5" >exp(coef) lower 95%</th>
#       <th id="T_fd945_level0_col6" class="col_heading level0 col6" >exp(coef) upper 95%</th>
#       <th id="T_fd945_level0_col7" class="col_heading level0 col7" >cmp to</th>
#       <th id="T_fd945_level0_col8" class="col_heading level0 col8" >z</th>
#       <th id="T_fd945_level0_col9" class="col_heading level0 col9" >p</th>
# ...

# %%
#sedentary analyses

# %%
df4 = df.dropna(subset=['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'pa_sed_convert', 'dias_bp_ave', 'sys_bp_ave', 'white_yes', 'comorb_sum'])

# %%
df4 = df4.loc[:, ['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_sed_convert', 'comorb_sum']]
df4 = df4[['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum',  'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_sed_convert', 'comorb_sum' ]]
#fulladjust_allcevd_data = pd.get_dummies(fulladjust_allcevd, columns=['alc_freq', 'smok_stat'])
cph = CoxPHFitter(penalizer=0.0001)
cph.fit(df4, duration_col='cevd_t2e', event_col='cevd_event') 
summary_df = cph.summary 
summary_df.style.format({'p': '{:.5f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_f59ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f59ee_level0_col0" class="col_heading level0 col0" >coef</th>
#       <th id="T_f59ee_level0_col1" class="col_heading level0 col1" >exp(coef)</th>
#       <th id="T_f59ee_level0_col2" class="col_heading level0 col2" >se(coef)</th>
#       <th id="T_f59ee_level0_col3" class="col_heading level0 col3" >coef lower 95%</th>
#       <th id="T_f59ee_level0_col4" class="col_heading level0 col4" >coef upper 95%</th>
#       <th id="T_f59ee_level0_col5" class="col_heading level0 col5" >exp(coef) lower 95%</th>
#       <th id="T_f59ee_level0_col6" class="col_heading level0 col6" >exp(coef) upper 95%</th>
#       <th id="T_f59ee_level0_col7" class="col_heading level0 col7" >cmp to</th>
#       <th id="T_f59ee_level0_col8" class="col_heading level0 col8" >z</th>
#       <th id="T_f59ee_level0_col9" class="col_heading level0 col9" >p</th>
# ...

# %%
#light pa

# %%
df5 = df.dropna(subset=['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'pa_light_convert', 'dias_bp_ave', 'sys_bp_ave', 'white_yes', 'comorb_sum'])

# %%
df5 = df5.loc[:, ['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_light_convert', 'comorb_sum']]
df5 = df5[['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum',  'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_light_convert', 'comorb_sum' ]]
#fulladjust_allcevd_data = pd.get_dummies(fulladjust_allcevd, columns=['alc_freq', 'smok_stat'])
cph = CoxPHFitter(penalizer=0.0001)
cph.fit(df5, duration_col='cevd_t2e', event_col='cevd_event') 
summary_df = cph.summary 
summary_df.style.format({'p': '{:.5f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc703">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc703_level0_col0" class="col_heading level0 col0" >coef</th>
#       <th id="T_dc703_level0_col1" class="col_heading level0 col1" >exp(coef)</th>
#       <th id="T_dc703_level0_col2" class="col_heading level0 col2" >se(coef)</th>
#       <th id="T_dc703_level0_col3" class="col_heading level0 col3" >coef lower 95%</th>
#       <th id="T_dc703_level0_col4" class="col_heading level0 col4" >coef upper 95%</th>
#       <th id="T_dc703_level0_col5" class="col_heading level0 col5" >exp(coef) lower 95%</th>
#       <th id="T_dc703_level0_col6" class="col_heading level0 col6" >exp(coef) upper 95%</th>
#       <th id="T_dc703_level0_col7" class="col_heading level0 col7" >cmp to</th>
#       <th id="T_dc703_level0_col8" class="col_heading level0 col8" >z</th>
#       <th id="T_dc703_level0_col9" class="col_heading level0 col9" >p</th>
# ...

# %%
#sleep analyses

# %%
df6 = df.dropna(subset=['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'pa_sleep_convert', 'dias_bp_ave', 'sys_bp_ave', 'white_yes', 'comorb_sum'])

# %%
df6 = df6.loc[:, ['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_sleep_convert', 'comorb_sum']]
df6 = df6[['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum',  'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_sleep_convert', 'comorb_sum' ]]
#fulladjust_allcevd_data = pd.get_dummies(fulladjust_allcevd, columns=['alc_freq', 'smok_stat'])
cph = CoxPHFitter(penalizer=0.0001)
cph.fit(df6, duration_col='cevd_t2e', event_col='cevd_event') 
summary_df = cph.summary 
summary_df.style.format({'p': '{:.5f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_c66ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c66ef_level0_col0" class="col_heading level0 col0" >coef</th>
#       <th id="T_c66ef_level0_col1" class="col_heading level0 col1" >exp(coef)</th>
#       <th id="T_c66ef_level0_col2" class="col_heading level0 col2" >se(coef)</th>
#       <th id="T_c66ef_level0_col3" class="col_heading level0 col3" >coef lower 95%</th>
#       <th id="T_c66ef_level0_col4" class="col_heading level0 col4" >coef upper 95%</th>
#       <th id="T_c66ef_level0_col5" class="col_heading level0 col5" >exp(coef) lower 95%</th>
#       <th id="T_c66ef_level0_col6" class="col_heading level0 col6" >exp(coef) upper 95%</th>
#       <th id="T_c66ef_level0_col7" class="col_heading level0 col7" >cmp to</th>
#       <th id="T_c66ef_level0_col8" class="col_heading level0 col8" >z</th>
#       <th id="T_c66ef_level0_col9" class="col_heading level0 col9" >p</th>
# ...

# %%
df7 = df.dropna(subset=['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'pa_sleep_convert_levels', 'dias_bp_ave', 'sys_bp_ave', 'white_yes', 'comorb_sum'])

# %%
df7 = df7.loc[:, ['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum', 'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_sleep_convert_levels', 'comorb_sum']]
df7 = df7[['cevd_event', 'cevd_t2e', 'age_i0', 'male', "alc_freq_filter", "smok_filter", 'bmi', "full_screen_time", "employ_status_array_filter_1",  "gov_assistance_filter", "dep_diag_yes", 'comorb_sum',  'white_yes', 'dias_bp_ave', 'sys_bp_ave', 'pa_sleep_convert_levels', 'comorb_sum' ]]
#fulladjust_allcevd_data = pd.get_dummies(fulladjust_allcevd, columns=['alc_freq', 'smok_stat'])
cph = CoxPHFitter(penalizer=0.0001)
cph.fit(df7, duration_col='cevd_t2e', event_col='cevd_event') 
summary_df = cph.summary 
summary_df.style.format({'p': '{:.5f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_7ab0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ab0e_level0_col0" class="col_heading level0 col0" >coef</th>
#       <th id="T_7ab0e_level0_col1" class="col_heading level0 col1" >exp(coef)</th>
#       <th id="T_7ab0e_level0_col2" class="col_heading level0 col2" >se(coef)</th>
#       <th id="T_7ab0e_level0_col3" class="col_heading level0 col3" >coef lower 95%</th>
#       <th id="T_7ab0e_level0_col4" class="col_heading level0 col4" >coef upper 95%</th>
#       <th id="T_7ab0e_level0_col5" class="col_heading level0 col5" >exp(coef) lower 95%</th>
#       <th id="T_7ab0e_level0_col6" class="col_heading level0 col6" >exp(coef) upper 95%</th>
#       <th id="T_7ab0e_level0_col7" class="col_heading level0 col7" >cmp to</th>
#       <th id="T_7ab0e_level0_col8" class="col_heading level0 col8" >z</th>
#       <th id="T_7ab0e_level0_col9" class="col_heading level0 col9" >p</th>
# ...
