# %%
require(foreign)
require(ggplot2)
require(MASS)
# Out:
# Loading required package: foreign
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘foreign’”
# Loading required package: ggplot2
#
# Loading required package: MASS

# %%
#comorbid_sum =0

# %%
import_file <- "cevd_first_model_sa.csv"
data <- read.csv(import_file)

# %%
#convert all PA behavior data to integers
data$pa_sleep_convert <- as.integer(data$pa_sleep_convert)
data$pa_sed_convert <- as.integer(data$pa_sed_convert)
data$pa_light_convert <- as.integer(data$pa_light_convert)
data$pa_mv_convert <- as.integer(data$pa_mv_convert)

# %%
#count number of future CeVD events by type
data$f01_event <- as.integer(data$f01_event)
count_events <- sum(data$f01_event == 1, na.rm = TRUE)
cat("Number of future F01 diagnoses:", count_events, "\n")

data$g45_event <- as.integer(data$g45_event)
count_events <- sum(data$g45_event == 1, na.rm = TRUE)
cat("Number of future g45 diagnoses:", count_events, "\n")

data$g46_event <- as.integer(data$g46_event)
count_events <- sum(data$g46_event == 1, na.rm = TRUE)
cat("Number of future g46 diagnoses:", count_events, "\n")

data$h34_event <- as.integer(data$h34_event)
count_events <- sum(data$h34_event == 1, na.rm = TRUE)
cat("Number of future h34 diagnoses:", count_events, "\n")

data$i60_event <- as.integer(data$i60_event)
count_events <- sum(data$i60_event == 1, na.rm = TRUE)
cat("Number of future i60 diagnoses:", count_events, "\n")

data$i61_event <- as.integer(data$i61_event)
count_events <- sum(data$i61_event == 1, na.rm = TRUE)
cat("Number of future i61 diagnoses:", count_events, "\n")

data$i62_event <- as.integer(data$i62_event)
count_events <- sum(data$i62_event == 1, na.rm = TRUE)
cat("Number of future i62 diagnoses:", count_events, "\n")

data$i63_event <- as.integer(data$i63_event)
count_events <- sum(data$i63_event == 1, na.rm = TRUE)
cat("Number of future i63 diagnoses:", count_events, "\n")

data$i64_event <- as.integer(data$i64_event)
count_events <- sum(data$i64_event == 1, na.rm = TRUE)
cat("Number of future i64 diagnoses:", count_events, "\n")

data$i65_event <- as.integer(data$i65_event)
count_events <- sum(data$i65_event == 1, na.rm = TRUE)
cat("Number of future i65 diagnoses:", count_events, "\n")

data$i66_event <- as.integer(data$i66_event)
count_events <- sum(data$i66_event == 1, na.rm = TRUE)
cat("Number of future i66 diagnoses:", count_events, "\n")

data$i67_event <- as.integer(data$i67_event)
count_events <- sum(data$i67_event == 1, na.rm = TRUE)
cat("Number of future i67 diagnoses:", count_events, "\n")

data$i68_event <- as.integer(data$i68_event)
count_events <- sum(data$i68_event == 1, na.rm = TRUE)
cat("Number of future i68 diagnoses:", count_events, "\n")

data$i69_event <- as.integer(data$i69_event)
count_events <- sum(data$i69_event == 1, na.rm = TRUE)
cat("Number of future i69 diagnoses:", count_events, "\n")
# Out:
# Number of future F01 diagnoses: 24
# Number of future g45 diagnoses: 192
# Number of future g46 diagnoses: 9
# Number of future h34 diagnoses: 58
# Number of future i60 diagnoses: 53
# Number of future i61 diagnoses: 66
# Number of future i62 diagnoses: 35
# Number of future i63 diagnoses: 278
# Number of future i64 diagnoses: 66
# Number of future i65 diagnoses: 64
# Number of future i66 diagnoses: 6
# Number of future i67 diagnoses: 301
# Number of future i68 diagnoses: 5
# Number of future i69 diagnoses: 51

# %%
#sleep mean and sd
mean_pa_sleep_convert <- mean(subset(data, cevd_event == 1)$pa_sleep_convert, na.rm = TRUE)
sd_pa_sleep_convert <- sd(subset(data, cevd_event == 1)$pa_sleep_convert, na.rm = TRUE)
cat("Mean sleep - exp:", mean_pa_sleep_convert, "\n")
cat("Standard Deviation sleep - exp:", sd_pa_sleep_convert, "\n")
mean_pa_sleep_convert <- mean(subset(data, cevd_event == 0)$pa_sleep_convert, na.rm = TRUE)
sd_pa_sleep_convert <- sd(subset(data, cevd_event == 0)$pa_sleep_convert, na.rm = TRUE)
cat("Mean sleep - control:", mean_pa_sleep_convert, "\n")
cat("Standard Deviation sleep - control:", sd_pa_sleep_convert, "\n")
#sed mean and sd
mean_pa_sed_convert <- mean(subset(data, cevd_event == 1)$pa_sed_convert, na.rm = TRUE)
sd_pa_sed_convert <- sd(subset(data, cevd_event == 1)$pa_sed_convert, na.rm = TRUE)
cat("Mean sed - exp':", mean_pa_sed_convert, "\n")
cat("Standard Deviation sed - exp':", sd_pa_sed_convert, "\n")
mean_pa_sed_convert <- mean(subset(data, cevd_event == 0)$pa_sed_convert, na.rm = TRUE)
sd_pa_sed_convert <- sd(subset(data, cevd_event == 0)$pa_sed_convert, na.rm = TRUE)
cat("Mean sed - control':", mean_pa_sed_convert, "\n")
cat("Standard Deviation sed - control':", sd_pa_sed_convert, "\n")
#lpa mean and sd
mean_pa_light_convert <- mean(subset(data, cevd_event == 1)$pa_light_convert, na.rm = TRUE)
sd_pa_light_convert <- sd(subset(data, cevd_event == 1)$pa_light_convert, na.rm = TRUE)
cat("Mean lpa - exp:", mean_pa_light_convert, "\n")
cat("Standard Deviation  lpa - exp:", sd_pa_light_convert, "\n")
mean_pa_light_convert <- mean(subset(data, cevd_event == 0)$pa_light_convert, na.rm = TRUE)
sd_pa_light_convert <- sd(subset(data, cevd_event == 0)$pa_light_convert, na.rm = TRUE)
cat("Mean of  lpa - control:", mean_pa_light_convert, "\n")
cat("Standard Deviation  lpa - control:", sd_pa_light_convert, "\n")
#mvpa mean and sd
mean_pa_mv_convert <- mean(subset(data, cevd_event == 1)$pa_mv_convert, na.rm = TRUE)
sd_pa_mv_convert <- sd(subset(data, cevd_event == 1)$pa_mv_convert, na.rm = TRUE)
cat("Mean mvpa - exp:", mean_pa_mv_convert, "\n")
cat("Standard Deviation mvpa - exp:", sd_pa_mv_convert, "\n")
mean_pa_mv_convert <- mean(subset(data, cevd_event == 0)$pa_mv_convert, na.rm = TRUE)
sd_pa_mv_convert <- sd(subset(data, cevd_event == 0)$pa_mv_convert, na.rm = TRUE)
cat("Mean mvpa - control':", mean_pa_mv_convert, "\n")
cat("Standard Deviation mvpa - control:", sd_pa_mv_convert, "\n")
# Out:
# Mean sleep - exp: 523.7819
# Standard Deviation sleep - exp: 80.19778
# Mean sleep - control: 523.6566
# Standard Deviation sleep - control: 75.88451
# Mean sed - exp': 557.7922
# Standard Deviation sed - exp': 106.0748
# Mean sed - control': 558.6286
# Standard Deviation sed - control': 108.422
# Mean lpa - exp: 314.1837
# Standard Deviation  lpa - exp: 99.76536
# Mean of  lpa - control: 311.837
# Standard Deviation  lpa - control: 99.59189
# Mean mvpa - exp: 42.28014
# Standard Deviation mvpa - exp: 36.06717
# Mean mvpa - control': 43.88923
# Standard Deviation mvpa - control: 35.54863

# %%
#create binary age variable
data$age_i0 <- as.integer(data$age_i0, na.rm = TRUE)
data$age_levels <- ifelse(data$age_i0 < 60, 0, 1)
data$age_levels <- as.integer(data$age_levels)
head(data$age_levels)
# Out:
# [1] 0 0 0 0 0 0

# %%
#unadjusted sleep IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event, data = data,
#     init.theta = 44.38812566, link = log)
#
# Coefficients:
#              Estimate Std. Error  z value Pr(>|z|)
# (Intercept) 6.2608360  0.0007493 8356.070   <2e-16 ***
# cevd_event  0.0002393  0.0053496    0.045    0.964
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(44.3881) family taken to be 1)
#
#     Null deviance: 45744  on 44402  degrees of freedom
# Residual deviance: 45744  on 44401  degrees of freedom
# AIC: 517677
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  44.388
#           Std. Err.:  0.329
#
#  2 x log-likelihood:  -517671.464
# Waiting for profiling to be done...
#             Estimate     2.5 %       97.5 %
# (Intercept) 6.2608360334  6.25936782 6.26230485
# cevd_event  0.0002392664 -0.01023096 0.01073924
#             Estimate   2.5 %       97.5 %
# (Intercept) 523.656552 522.8882772 524.426273
# ...

# %%
#adjusted sleep IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 45.22244523, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.193e+00  1.020e-02 607.194  < 2e-16 ***
# cevd_event                   -7.180e-03  5.335e-03  -1.346  0.17835
# dias_bp_ave                  -3.475e-05  7.148e-05  -0.486  0.62685
# sys_bp_ave                    5.156e-04  1.231e-04   4.188 2.82e-05 ***
# white_yes                     3.147e-02  4.046e-03   7.778 7.34e-15 ***
# age_i0                        8.876e-04  1.161e-04   7.648 2.04e-14 ***
# male                         -1.899e-02  1.576e-03 -12.055  < 2e-16 ***
# ...

# %%
#udadjusted sed IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event, data = data, init.theta = 26.45723147,
#     link = log)
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  6.3254848  0.0009536 6633.19   <2e-16 ***
# cevd_event  -0.0014983  0.0068090   -0.22    0.826
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(26.4572) family taken to be 1)
#
#     Null deviance: 44756  on 44402  degrees of freedom
# Residual deviance: 44756  on 44401  degrees of freedom
# AIC: 543305
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  26.457
#           Std. Err.:  0.185
#
#  2 x log-likelihood:  -543299.196
# Waiting for profiling to be done...
#             Estimate     2.5 %      97.5 %
# (Intercept)  6.325484802  6.3236163 6.32735438
# cevd_event  -0.001498323 -0.0148178 0.01187311
#             Estimate    2.5 %       97.5 %
# (Intercept) 558.6285721 557.5857408 559.673947
# ...

# %%
#adjusted sed IRR and CI and pvalue
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum + gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 28.59816036, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.108e+00  1.261e-02 484.210  < 2e-16 ***
# cevd_event                   -1.633e-04  6.600e-03  -0.025 0.980267
# dias_bp_ave                  -6.535e-04  8.845e-05  -7.388 1.49e-13 ***
# sys_bp_ave                    8.139e-04  1.523e-04   5.344 9.11e-08 ***
# white_yes                     2.569e-04  4.998e-03   0.051 0.959003
# age_i0                       -3.881e-04  1.435e-04  -2.704 0.006855 **
# male                          5.970e-02  1.948e-03  30.645  < 2e-16 ***
# ...

# %%
#unadjusted lpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event, data = data,
#     init.theta = 9.784465781, link = log)
#
# Coefficients:
#             Estimate Std. Error  z value Pr(>|z|)
# (Intercept) 5.742481   0.001556 3690.317   <2e-16 ***
# cevd_event  0.007497   0.011109    0.675      0.5
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(9.7845) family taken to be 1)
#
#     Null deviance: 45248  on 44402  degrees of freedom
# Residual deviance: 45247  on 44401  degrees of freedom
# AIC: 533066
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  9.7845
#           Std. Err.:  0.0669
#
#  2 x log-likelihood:  -533059.5550
# Waiting for profiling to be done...
#             Estimate    2.5 %       97.5 %
# (Intercept) 5.742480521  5.73943209 5.74553187
# cevd_event  0.007497316 -0.01420523 0.02934275
#             Estimate   2.5 %       97.5 %
# (Intercept) 311.836971 310.8878046 312.789947
# ...

# %%
#adjusted lpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 10.62212987, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0990162  0.0205255 297.143  < 2e-16 ***
# cevd_event                    0.0178041  0.0107399   1.658 0.097370 .
# dias_bp_ave                   0.0010513  0.0001439   7.306 2.75e-13 ***
# sys_bp_ave                   -0.0020028  0.0002479  -8.080 6.48e-16 ***
# white_yes                    -0.0638968  0.0081306  -7.859 3.88e-15 ***
# age_i0                        0.0002015  0.0002337   0.862 0.388447
# male                         -0.1351129  0.0031730 -42.582  < 2e-16 ***
# ...

# %%
#unadjusted mvpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event, data = data, init.theta = 1.469460501,
#     link = log)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)  3.781669   0.004019 940.839   <2e-16 ***
# cevd_event  -0.037352   0.028716  -1.301    0.193
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for Negative Binomial(1.4695) family taken to be 1)
#
#     Null deviance: 50068  on 44402  degrees of freedom
# Residual deviance: 50066  on 44401  degrees of freedom
# AIC: 422441
#
# Number of Fisher Scoring iterations: 1
#
#
#               Theta:  1.46946
#           Std. Err.:  0.00971
#
#  2 x log-likelihood:  -422434.57600
# Waiting for profiling to be done...
#             Estimate    2.5 %       97.5 %
# (Intercept)  3.78166898  3.77380065 3.78955668
# cevd_event  -0.03735156 -0.09316503 0.01940988
#             Estimate   2.5 %      97.5 %
# (Intercept) 43.8892309 43.5452512 44.236785
# ...

# %%
#adjusted mvpa IRR and CI and pvalue
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data,
#     init.theta = 1.632207602, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9114545  0.0525560  93.452  < 2e-16 ***
# cevd_event                   -0.0337254  0.0275081  -1.226 0.220192
# dias_bp_ave                   0.0009802  0.0003684   2.661 0.007792 **
# sys_bp_ave                   -0.0018571  0.0006343  -2.928 0.003414 **
# white_yes                     0.0716152  0.0208573   3.434 0.000596 ***
# age_i0                       -0.0077333  0.0005976 -12.941  < 2e-16 ***
# male                          0.4182692  0.0081046  51.609  < 2e-16 ***
# ...

# %%
#

# %%
#sensitivity analysis 2

# %%
#

# %%
import_file <- "cevd_first_model_sa_cevdt2e_1yr.csv"
data <- read.csv(import_file)

# %%
#create binary age variable
data$age_i0 <- as.integer(data$age_i0, na.rm = TRUE)
data$pa_sleep_convert <- as.integer(data$pa_sleep_convert, na.rm = TRUE)
data$pa_sed_convert <- as.integer(data$pa_sed_convert, na.rm = TRUE)
data$pa_light_convert <- as.integer(data$pa_light_convert, na.rm = TRUE)
data$pa_mv_convert <- as.integer(data$pa_mv_convert, na.rm = TRUE)
data$cevd_event <- as.integer(data$cevd_event, na.rm = TRUE)
data$male <- as.integer(data$male, na.rm = TRUE)
data$alc_freq_filter <- as.integer(data$alc_freq_filter, na.rm = TRUE)
data$smok_stat <- as.integer(data$smok_stat, na.rm = TRUE)
data$bmi_filter <- as.integer(data$bmi_filter, na.rm = TRUE)
data$full_screen_time_filter <- as.integer(data$full_screen_time_filter, na.rm = TRUE)
data$employ_status_array_filter <- as.integer(data$employ_status_array_filter, na.rm = TRUE)
data$comborb_sum <- as.integer(data$comorb_sum, na.rm = TRUE)
data$gov_assistance_filter <- as.integer(data$gov_assistance_filter, na.rm = TRUE)
data$dep_diag_yes <- as.integer(data$dep_diag_yes, na.rm = TRUE)   
data$age_levels <- ifelse(data$age_i0 < 60, 0, 1)
data$age_levels <- as.integer(data$age_levels)
head(data$age_levels)
# Out:
# [1] 0 0 0 0 0 1

# %%
#create dfs for different cevd t2es
data_cevd_1 <- data[data$cevd_t2e_filter_1yr == 0 | data$cevd_t2e_filter_1yr == 1, ]
data_cevd_2 <- data[data$cevd_t2e_filter_1yr == 0 | data$cevd_t2e_filter_1yr == 2, ]
data_cevd_3 <- data[data$cevd_t2e_filter_1yr == 0 | data$cevd_t2e_filter_1yr == 3, ]

# %%
nrow(data_cevd_1)
# Out:
# [1] 74153

# %%
data_cevd_1_com <- data[data$comorb_sum > 0, ]
data_cevd_1_nocom <- data[data$comorb_sum == 0, ]

# %%
nrow(data_cevd_1_com)
# Out:
# [1] 31676

# %%
nrow(data_cevd_1_nocom)
# Out:
# [1] 44403

# %%
#cevd = 1

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1,
#     init.theta = 45.11086498, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.191e+00  8.000e-03 773.869  < 2e-16 ***
# cevd_event                    1.080e-02  1.060e-02   1.019  0.30826
# dias_bp_ave                  -1.167e-04  5.073e-05  -2.300  0.02142 *
# sys_bp_ave                    5.281e-04  8.904e-05   5.931 3.01e-09 ***
# white_yes                     3.039e-02  3.132e-03   9.702  < 2e-16 ***
# age_i0                        1.046e-03  9.328e-05  11.214  < 2e-16 ***
# male                         -1.422e-02  1.209e-03 -11.766  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_nocom))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1_nocom,
#     init.theta = 45.22244523, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.193e+00  1.020e-02 607.194  < 2e-16 ***
# cevd_event                   -7.180e-03  5.335e-03  -1.346  0.17835
# dias_bp_ave                  -3.475e-05  7.148e-05  -0.486  0.62685
# sys_bp_ave                    5.156e-04  1.231e-04   4.188 2.82e-05 ***
# white_yes                     3.147e-02  4.046e-03   7.778 7.34e-15 ***
# age_i0                        8.876e-04  1.161e-04   7.648 2.04e-14 ***
# male                         -1.899e-02  1.576e-03 -12.055  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1  +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_com))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     gov_assistance_filter + dep_diag_yes, data = data_cevd_1_com,
#     init.theta = 44.89076954, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1920964  0.0132921 465.849  < 2e-16 ***
# cevd_event                   -0.0010391  0.0044858  -0.232 0.816810
# dias_bp_ave                  -0.0001763  0.0000696  -2.533 0.011317 *
# sys_bp_ave                    0.0005067  0.0001260   4.021 5.79e-05 ***
# white_yes                     0.0267687  0.0048159   5.558 2.72e-08 ***
# age_i0                        0.0012867  0.0001540   8.356  < 2e-16 ***
# male                         -0.0063259  0.0018369  -3.444 0.000574 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1,
#     init.theta = 29.10354314, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.099e+00  9.802e-03 622.260  < 2e-16 ***
# cevd_event                    5.391e-03  1.299e-02   0.415  0.67823
# dias_bp_ave                  -5.667e-04  6.219e-05  -9.113  < 2e-16 ***
# sys_bp_ave                    5.906e-04  1.091e-04   5.413 6.20e-08 ***
# white_yes                     6.978e-03  3.833e-03   1.820  0.06869 .
# age_i0                       -3.385e-04  1.143e-04  -2.962  0.00305 **
# male                          5.675e-02  1.481e-03  38.319  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes+age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_nocom))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1_nocom,
#     init.theta = 28.59816036, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.108e+00  1.261e-02 484.210  < 2e-16 ***
# cevd_event                   -1.633e-04  6.600e-03  -0.025 0.980267
# dias_bp_ave                  -6.535e-04  8.845e-05  -7.388 1.49e-13 ***
# sys_bp_ave                    8.139e-04  1.523e-04   5.344 9.11e-08 ***
# white_yes                     2.569e-04  4.998e-03   0.051 0.959003
# age_i0                       -3.881e-04  1.435e-04  -2.704 0.006855 **
# male                          5.970e-02  1.948e-03  30.645  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1  +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_com))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     gov_assistance_filter + dep_diag_yes, data = data_cevd_1_com,
#     init.theta = 29.86374397, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.053e+00  1.605e-02 377.111  < 2e-16 ***
# cevd_event                    1.649e-02  5.417e-03   3.045  0.00233 **
# dias_bp_ave                  -4.353e-04  8.408e-05  -5.178 2.25e-07 ***
# sys_bp_ave                    4.092e-04  1.522e-04   2.689  0.00717 **
# white_yes                     1.556e-02  5.811e-03   2.677  0.00743 **
# age_i0                        1.407e-04  1.859e-04   0.756  0.44936
# male                          5.253e-02  2.218e-03  23.677  < 2e-16 ***
# alc_freq_filter               2.593e-03  1.582e-03   1.639  0.10116
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1,
#     init.theta = 10.38941657, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1312305  0.0162643 376.975  < 2e-16 ***
# cevd_event                   -0.0117536  0.0215876  -0.544   0.5861
# dias_bp_ave                   0.0011127  0.0001032  10.783  < 2e-16 ***
# sys_bp_ave                   -0.0017332  0.0001811  -9.570  < 2e-16 ***
# white_yes                    -0.0741939  0.0063574 -11.670  < 2e-16 ***
# age_i0                       -0.0001028  0.0001897  -0.542   0.5879
# male                         -0.1371479  0.0024593 -55.766  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_nocom))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1_nocom,
#     init.theta = 10.62212987, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.0990162  0.0205255 297.143  < 2e-16 ***
# cevd_event                    0.0178041  0.0107399   1.658 0.097370 .
# dias_bp_ave                   0.0010513  0.0001439   7.306 2.75e-13 ***
# sys_bp_ave                   -0.0020028  0.0002479  -8.080 6.48e-16 ***
# white_yes                    -0.0638968  0.0081306  -7.859 3.88e-15 ***
# age_i0                        0.0002015  0.0002337   0.862 0.388447
# male                         -0.1351129  0.0031730 -42.582  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_com))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     gov_assistance_filter + dep_diag_yes, data = data_cevd_1_com,
#     init.theta = 9.990839273, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.2302444  0.0274957 226.589  < 2e-16 ***
# cevd_event                   -0.0245520  0.0092920  -2.642 0.008235 **
# dias_bp_ave                   0.0010585  0.0001440   7.350 1.99e-13 ***
# sys_bp_ave                   -0.0015112  0.0002608  -5.794 6.87e-09 ***
# white_yes                    -0.0845881  0.0099474  -8.504  < 2e-16 ***
# age_i0                       -0.0011790  0.0003186  -3.700 0.000216 ***
# male                         -0.1413873  0.0038024 -37.184  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1,
#     init.theta = 1.516726851, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.0087322  0.0427322 117.212  < 2e-16 ***
# cevd_event                   -0.1500811  0.0568634  -2.639  0.00831 **
# dias_bp_ave                   0.0008349  0.0002712   3.078  0.00208 **
# sys_bp_ave                   -0.0007680  0.0004759  -1.614  0.10654
# white_yes                     0.0548898  0.0167355   3.280  0.00104 **
# age_i0                       -0.0088884  0.0004978 -17.855  < 2e-16 ***
# male                          0.4303612  0.0064501  66.722  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_nocom))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_1_nocom,
#     init.theta = 1.632207602, link = log)
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9114545  0.0525560  93.452  < 2e-16 ***
# cevd_event                   -0.0337254  0.0275081  -1.226 0.220192
# dias_bp_ave                   0.0009802  0.0003684   2.661 0.007792 **
# sys_bp_ave                   -0.0018571  0.0006343  -2.928 0.003414 **
# white_yes                     0.0716152  0.0208573   3.434 0.000596 ***
# age_i0                       -0.0077333  0.0005976 -12.941  < 2e-16 ***
# male                          0.4182692  0.0081046  51.609  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + comorb_sum+dias_bp_ave+ sys_bp_ave + white_yes+ age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1  +gov_assistance_filter +dep_diag_yes, data = data_cevd_1_com))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + comorb_sum + dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     gov_assistance_filter + dep_diag_yes, data = data_cevd_1_com,
#     init.theta = 1.361476691, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.2599993  0.0747831  70.337  < 2e-16 ***
# cevd_event                   -0.0352821  0.0252977  -1.395   0.1631
# comorb_sum                   -0.0783793  0.0075088 -10.438  < 2e-16 ***
# dias_bp_ave                   0.0006943  0.0003928   1.768   0.0771 .
# sys_bp_ave                   -0.0001263  0.0007106  -0.178   0.8589
# white_yes                     0.0459461  0.0271244   1.694   0.0903 .
# age_i0                       -0.0114717  0.0008727 -13.145  < 2e-16 ***
# ...

# %%
#cevd = 2

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_2,
#     init.theta = 45.07609953, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.191e+00  8.001e-03 773.775  < 2e-16 ***
# cevd_event                   -8.875e-03  1.129e-02  -0.786  0.43164
# dias_bp_ave                  -1.163e-04  5.077e-05  -2.292  0.02193 *
# sys_bp_ave                    5.234e-04  8.910e-05   5.874 4.25e-09 ***
# white_yes                     3.030e-02  3.132e-03   9.675  < 2e-16 ***
# age_i0                        1.051e-03  9.333e-05  11.257  < 2e-16 ***
# male                         -1.427e-02  1.209e-03 -11.801  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_2,
#     init.theta = 29.1068619, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.098e+00  9.799e-03 622.385  < 2e-16 ***
# cevd_event                    2.781e-02  1.381e-02   2.013  0.04411 *
# dias_bp_ave                  -5.673e-04  6.221e-05  -9.119  < 2e-16 ***
# sys_bp_ave                    6.004e-04  1.091e-04   5.501 3.78e-08 ***
# white_yes                     6.921e-03  3.832e-03   1.806  0.07087 .
# age_i0                       -3.366e-04  1.143e-04  -2.945  0.00323 **
# male                          5.671e-02  1.481e-03  38.291  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_2,
#     init.theta = 10.38236679, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1330214  0.0162654 377.058  < 2e-16 ***
# cevd_event                   -0.0311333  0.0229775  -1.355   0.1754
# dias_bp_ave                   0.0011161  0.0001033  10.809  < 2e-16 ***
# sys_bp_ave                   -0.0017537  0.0001812  -9.676  < 2e-16 ***
# white_yes                    -0.0741859  0.0063574 -11.669  < 2e-16 ***
# age_i0                       -0.0001132  0.0001898  -0.597   0.5508
# male                         -0.1370153  0.0024605 -55.687  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_2,
#     init.theta = 1.515933227, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.0061747  0.0427312 117.155  < 2e-16 ***
# cevd_event                    0.0029315  0.0603005   0.049  0.96123
# dias_bp_ave                   0.0008029  0.0002714   2.958  0.00309 **
# sys_bp_ave                   -0.0006972  0.0004761  -1.464  0.14311
# white_yes                     0.0562844  0.0167339   3.363  0.00077 ***
# age_i0                       -0.0088780  0.0004981 -17.826  < 2e-16 ***
# male                          0.4303213  0.0064524  66.692  < 2e-16 ***
# ...

# %%
#cevd =3

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_3,
#     init.theta = 45.08494898, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.193e+00  7.934e-03 780.542  < 2e-16 ***
# cevd_event                   -5.040e-03  3.793e-03  -1.329  0.18398
# dias_bp_ave                  -1.191e-04  4.998e-05  -2.384  0.01714 *
# sys_bp_ave                    5.370e-04  8.780e-05   6.117 9.55e-10 ***
# white_yes                     2.987e-02  3.105e-03   9.620  < 2e-16 ***
# age_i0                        1.033e-03  9.253e-05  11.163  < 2e-16 ***
# male                         -1.401e-02  1.197e-03 -11.705  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_3,
#     init.theta = 29.08110833, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.098e+00  9.721e-03 627.280  < 2e-16 ***
# cevd_event                    8.328e-03  4.648e-03   1.792   0.0732 .
# dias_bp_ave                  -5.529e-04  6.127e-05  -9.024  < 2e-16 ***
# sys_bp_ave                    5.527e-04  1.076e-04   5.136 2.81e-07 ***
# white_yes                     6.875e-03  3.800e-03   1.809   0.0704 .
# age_i0                       -3.254e-04  1.134e-04  -2.870   0.0041 **
# male                          5.654e-02  1.466e-03  38.568  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_3,
#     init.theta = 10.34909598, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1323631  0.0161552 379.590  < 2e-16 ***
# cevd_event                   -0.0036124  0.0077316  -0.467   0.6403
# dias_bp_ave                   0.0010881  0.0001018  10.687  < 2e-16 ***
# sys_bp_ave                   -0.0016782  0.0001789  -9.381  < 2e-16 ***
# white_yes                    -0.0736221  0.0063125 -11.663  < 2e-16 ***
# age_i0                       -0.0001014  0.0001885  -0.538   0.5904
# male                         -0.1372093  0.0024383 -56.274  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter +dep_diag_yes, data = data_cevd_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter + dep_diag_yes, data = data_cevd_3,
#     init.theta = 1.511678875, link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   5.0013686  0.0424342 117.862  < 2e-16 ***
# cevd_event                   -0.0295945  0.0203272  -1.456 0.145418
# dias_bp_ave                   0.0008110  0.0002676   3.031 0.002436 **
# sys_bp_ave                   -0.0006998  0.0004699  -1.489 0.136425
# white_yes                     0.0584360  0.0166139   3.517 0.000436 ***
# age_i0                       -0.0088434  0.0004945 -17.884  < 2e-16 ***
# male                          0.4316630  0.0063934  67.517  < 2e-16 ***
# ...

# %%
#

# %%
#sensitivity analysis 3

# %%
#

# %%
import_file <- "cevd_first_model_sa_cevdt2eanddep.csv"
data <- read.csv(import_file)

# %%
#create binary age variable
data$age_i0 <- as.integer(data$age_i0, na.rm = TRUE)
data$pa_sleep_convert <- as.integer(data$pa_sleep_convert, na.rm = TRUE)
data$pa_sed_convert <- as.integer(data$pa_sed_convert, na.rm = TRUE)
data$pa_light_convert <- as.integer(data$pa_light_convert, na.rm = TRUE)
data$pa_mv_convert <- as.integer(data$pa_mv_convert, na.rm = TRUE)
data$cevd_event <- as.integer(data$cevd_event, na.rm = TRUE)
data$male <- as.integer(data$male, na.rm = TRUE)
data$alc_freq_filter <- as.integer(data$alc_freq_filter, na.rm = TRUE)
data$smok_filter <- as.integer(data$smok_filter, na.rm = TRUE)
data$bmi <- as.integer(data$bmi, na.rm = TRUE)
data$full_screen_time_filter <- as.integer(data$full_screen_time_filter, na.rm = TRUE)
data$employ_status_array_filter_1 <- as.integer(data$employ_status_array_filter_1, na.rm = TRUE)
data$comborb_sum <- as.integer(data$comorb_sum, na.rm = TRUE)
data$gov_assistance_filter <- as.integer(data$gov_assistance_filter, na.rm = TRUE)
data$dep_diag_yes <- as.integer(data$dep_diag_yes, na.rm = TRUE)   
data$age_levels <- ifelse(data$age_i0 < 60, 0, 1)
data$age_levels <- as.integer(data$age_levels)
data$dep_dur_filter <- as.integer(data$dep_dur_filter, na.rm = TRUE)  

head(data$age_levels)
# Out:
# [1] 0 0 0 0 0 1

# %%
data$dep_dur_filter <- as.integer(data$dep_dur_filter)

# %%
#create dfs for different cevd t2es
data_dep_1 <- data[data$dep_dur_filter == 0 | data$dep_dur_filter == 1, ]
data_dep_2 <- data[data$dep_dur_filter == 0 | data$dep_dur_filter == 2, ]
data_dep_3 <- data[data$dep_dur_filter == 0 | data$dep_dur_filter == 3, ]

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + age_i0 + +dias_bp_ave+ sys_bp_ave + white_yes+male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + age_i0 + +dias_bp_ave +
#     sys_bp_ave + white_yes + male + alc_freq_filter + smok_filter +
#     bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +
#     gov_assistance_filter, data = data_dep_1, init.theta = 1.535021827,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9779456  0.0436123 114.141  < 2e-16 ***
# cevd_event                   -0.0294666  0.0190491  -1.547 0.121893
# age_i0                       -0.0087866  0.0005108 -17.202  < 2e-16 ***
# dias_bp_ave                   0.0007866  0.0002747   2.864 0.004184 **
# sys_bp_ave                   -0.0007918  0.0004838  -1.637 0.101695
# white_yes                     0.0632781  0.0169106   3.742 0.000183 ***
# male                          0.4299473  0.0065608  65.532  < 2e-16 ***
# alc_freq_filter               0.0678298  0.0047367  14.320  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_2, init.theta = 1.543365559,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9690196  0.0438187 113.400  < 2e-16 ***
# cevd_event                   -0.0339028  0.0195852  -1.731 0.083444 .
# dias_bp_ave                   0.0007283  0.0002765   2.634 0.008434 **
# sys_bp_ave                   -0.0006435  0.0004866  -1.322 0.186042
# white_yes                     0.0624140  0.0169768   3.676 0.000237 ***
# age_i0                       -0.0086571  0.0005140 -16.842  < 2e-16 ***
# male                          0.4298134  0.0065938  65.184  < 2e-16 ***
# alc_freq_filter               0.0667463  0.0047657  14.006  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_mv_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_mv_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_3, init.theta = 1.525149686,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   4.9717221  0.0431229 115.292  < 2e-16 ***
# cevd_event                   -0.0321756  0.0192556  -1.671 0.094727 .
# dias_bp_ave                   0.0008551  0.0002718   3.146 0.001655 **
# sys_bp_ave                   -0.0007645  0.0004780  -1.599 0.109751
# white_yes                     0.0562539  0.0168511   3.338 0.000843 ***
# age_i0                       -0.0088074  0.0005044 -17.461  < 2e-16 ***
# male                          0.4303117  0.0064898  66.306  < 2e-16 ***
# alc_freq_filter               0.0702484  0.0046730  15.033  < 2e-16 ***
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_1, init.theta = 10.47028021,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1357902  0.0166390 368.759  < 2e-16 ***
# cevd_event                   -0.0081261  0.0072636  -1.119  0.26325
# dias_bp_ave                   0.0010498  0.0001047  10.024  < 2e-16 ***
# sys_bp_ave                   -0.0016042  0.0001846  -8.692  < 2e-16 ***
# white_yes                    -0.0739882  0.0064380 -11.492  < 2e-16 ***
# age_i0                       -0.0001467  0.0001951  -0.752  0.45198
# male                         -0.1376788  0.0025067 -54.924  < 2e-16 ***
# alc_freq_filter              -0.0058872  0.0018079  -3.256  0.00113 **
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event ++dias_bp_ave+ sys_bp_ave + white_yes  + age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_2, init.theta = 10.51541658,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.1381616  0.0167279 366.942  < 2e-16 ***
# cevd_event                   -0.0083148  0.0074716  -1.113  0.26577
# dias_bp_ave                   0.0010501  0.0001055   9.955  < 2e-16 ***
# sys_bp_ave                   -0.0016970  0.0001858  -9.136  < 2e-16 ***
# white_yes                    -0.0725242  0.0064669 -11.215  < 2e-16 ***
# age_i0                       -0.0001162  0.0001965  -0.592  0.55408
# male                         -0.1383679  0.0025208 -54.891  < 2e-16 ***
# alc_freq_filter              -0.0059812  0.0018201  -3.286  0.00102 **
# ...

# %%
summary(m1 <- glm.nb(pa_light_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_light_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_3, init.theta = 10.40377845,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.128e+00  1.645e-02 372.501  < 2e-16 ***
# cevd_event                   -9.454e-03  7.341e-03  -1.288   0.1978
# dias_bp_ave                   1.089e-03  1.036e-04  10.507  < 2e-16 ***
# sys_bp_ave                   -1.725e-03  1.823e-04  -9.462  < 2e-16 ***
# white_yes                    -7.349e-02  6.415e-03 -11.457  < 2e-16 ***
# age_i0                       -5.046e-05  1.926e-04  -0.262   0.7934
# male                         -1.366e-01  2.480e-03 -55.092  < 2e-16 ***
# alc_freq_filter              -4.952e-03  1.783e-03  -2.776   0.0055 **
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_1, init.theta = 29.27719299,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.097e+00  1.004e-02 607.439  < 2e-16 ***
# cevd_event                    9.072e-03  4.377e-03   2.073  0.03820 *
# dias_bp_ave                  -5.452e-04  6.318e-05  -8.629  < 2e-16 ***
# sys_bp_ave                    5.522e-04  1.113e-04   4.962 6.99e-07 ***
# white_yes                     6.089e-03  3.885e-03   1.567  0.11707
# age_i0                       -3.199e-04  1.177e-04  -2.719  0.00655 **
# male                          5.723e-02  1.511e-03  37.878  < 2e-16 ***
# alc_freq_filter               5.397e-03  1.090e-03   4.949 7.45e-07 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_2, init.theta = 29.35179758,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.097e+00  1.010e-02 603.718  < 2e-16 ***
# cevd_event                    1.105e-02  4.506e-03   2.452  0.01423 *
# dias_bp_ave                  -5.225e-04  6.369e-05  -8.203 2.34e-16 ***
# sys_bp_ave                    5.485e-04  1.121e-04   4.893 9.95e-07 ***
# white_yes                     6.858e-03  3.906e-03   1.756  0.07913 .
# age_i0                       -3.772e-04  1.186e-04  -3.181  0.00147 **
# male                          5.752e-02  1.521e-03  37.826  < 2e-16 ***
# alc_freq_filter               5.570e-03  1.099e-03   5.069 3.99e-07 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sed_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sed_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_3, init.theta = 29.21380315,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.098e+00  9.902e-03 615.759  < 2e-16 ***
# cevd_event                    1.093e-02  4.414e-03   2.475  0.01332 *
# dias_bp_ave                  -5.494e-04  6.239e-05  -8.807  < 2e-16 ***
# sys_bp_ave                    5.771e-04  1.097e-04   5.259 1.44e-07 ***
# white_yes                     7.328e-03  3.864e-03   1.897  0.05788 .
# age_i0                       -3.210e-04  1.159e-04  -2.769  0.00563 **
# male                          5.677e-02  1.491e-03  38.065  < 2e-16 ***
# alc_freq_filter               5.232e-03  1.073e-03   4.874 1.09e-06 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_1))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_1, init.theta = 45.57589986,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.191e+00  8.178e-03 757.022  < 2e-16 ***
# cevd_event                   -2.966e-03  3.566e-03  -0.832   0.4055
# dias_bp_ave                  -1.112e-04  5.145e-05  -2.162   0.0306 *
# sys_bp_ave                    5.091e-04  9.065e-05   5.617 1.95e-08 ***
# white_yes                     3.100e-02  3.169e-03   9.783  < 2e-16 ***
# age_i0                        1.061e-03  9.585e-05  11.073  < 2e-16 ***
# male                         -1.453e-02  1.231e-03 -11.804  < 2e-16 ***
# alc_freq_filter              -6.794e-03  8.881e-04  -7.650 2.01e-14 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_2))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_2, init.theta = 45.5572649,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.189e+00  8.240e-03 751.056  < 2e-16 ***
# cevd_event                   -4.325e-03  3.676e-03  -1.176   0.2394
# dias_bp_ave                  -1.280e-04  5.194e-05  -2.464   0.0137 *
# sys_bp_ave                    5.505e-04  9.145e-05   6.020 1.74e-09 ***
# white_yes                     2.974e-02  3.190e-03   9.323  < 2e-16 ***
# age_i0                        1.094e-03  9.674e-05  11.306  < 2e-16 ***
# male                         -1.459e-02  1.241e-03 -11.756  < 2e-16 ***
# alc_freq_filter              -6.875e-03  8.961e-04  -7.672 1.69e-14 ***
# ...

# %%
summary(m1 <- glm.nb(pa_sleep_convert ~ cevd_event + +dias_bp_ave+ sys_bp_ave + white_yes  +age_i0 + male + alc_freq_filter + smok_filter + bmi + full_screen_time + employ_status_array_filter_1 + comorb_sum +gov_assistance_filter, data = data_dep_3))
(est <- cbind(Estimate = coef(m1), confint(m1)))
exp(est)
# Out:
# Call:
# glm.nb(formula = pa_sleep_convert ~ cevd_event + +dias_bp_ave +
#     sys_bp_ave + white_yes + age_i0 + male + alc_freq_filter +
#     smok_filter + bmi + full_screen_time + employ_status_array_filter_1 +
#     comorb_sum + gov_assistance_filter, data = data_dep_3, init.theta = 45.11553377,
#     link = log)
#
# Coefficients:
#                                Estimate Std. Error z value Pr(>|z|)
# (Intercept)                   6.197e+00  8.097e-03 765.260  < 2e-16 ***
# cevd_event                   -3.572e-03  3.609e-03  -0.990 0.322299
# dias_bp_ave                  -1.317e-04  5.099e-05  -2.582 0.009815 **
# sys_bp_ave                    5.479e-04  8.970e-05   6.108 1.01e-09 ***
# white_yes                     2.969e-02  3.162e-03   9.390  < 2e-16 ***
# age_i0                        9.991e-04  9.479e-05  10.541  < 2e-16 ***
# male                         -1.470e-02  1.220e-03 -12.049  < 2e-16 ***
# alc_freq_filter              -7.360e-03  8.775e-04  -8.388  < 2e-16 ***
# ...
